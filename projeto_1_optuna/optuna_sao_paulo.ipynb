# %% [markdown]
# ## Bibliotecas

# %%
#import packages
import pandas as pd
import numpy as np
import os
import warnings
import optuna
from sklearn.metrics import root_mean_squared_error, mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor, VotingRegressor
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
import shap
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# ## Configurações

# %%
# Definir diretório
os.chdir('/home/joao/Área de Trabalho/tese')

# Evitar avisos
warnings.filterwarnings('ignore')

# %%
#load dataset
df = pd.read_excel('df_conjunto_sp.xlsx')

# %%
#rename columns
df = df.rename(columns={
    'semana':'week',
    'cesta_dieese':'dieese_basket',
    'carne':'meat',
    'leite':'milk',
    'feijao':'bean',
    'arroz':'rice',
    'farinha':'flour',
    'batata':'potato',
    'tomate':'tomato',
    'pao':'bread',
    'cafe':'coffee',
    'acucar':'sugar',
    'oleo':'lard/oil',
    'manteiga':'butter',
    'cesta_online':'online'
})esta_online':'online'
})

# %%
df.columns
# Out:
# Index(['week', 'dieese_basket', 'meat', 'milk', 'bean', 'rice', 'flour',
#        'batata', 'tomato', 'bread', 'coffee', 'banana', 'sugar', 'lard/oil',
#        'butter', 'online'],
#       dtype='object')

# %%
#create lagged dataset
k = 1 #number of lags
y_lag = df[['week','dieese_basket']][k:]
x_lag = df.copy()
x_lag = x_lag.drop(['week','dieese_basket'], axis=1)
x_lag = x_lag[:len(df)-k]
y_lag = y_lag.reset_index(drop=True)
x_lag = x_lag.reset_index(drop=True)
df_lag = pd.concat([y_lag,x_lag], axis=1)

# %%
#set X and y
X = df_lag.copy()
X = X.drop(['week','dieese_basket','online'], axis=1)
y = df_lag['dieese_basket']

# %%
def calculate_mape(y_true, y_pred):
    mask = y_true != 0
    if mask.sum() == 0:
        return 0
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

# %% [markdown]
# ## Random forest

# %%
#function Optuna -- RF
def objective(trial):
    # 1. Define hyperparameters to tune
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 2, 256)
    min_samples_split = trial.suggest_int('min_samples_split', 5, 100)
    max_depth = trial.suggest_int('max_depth', 5, 20, log=True)
    
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = RandomForestRegressor(
            n_estimators=n_estimators,
            max_leaf_nodes=max_leaf_nodes,
            min_samples_split=min_samples_split,
            max_depth=max_depth,
            random_state=42
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna RF
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:21:23,202] A new study created in memory with name: no-name-ab23e02d-0c6a-44cf-a039-b840b72a62f7
# [I 2026-06-29 16:21:26,058] Trial 0 finished with value: 31.69945110448735 and parameters: {'n_estimators': 106, 'max_leaf_nodes': 244, 'min_samples_split': 75, 'max_depth': 11}. Best is trial 0 with value: 31.69945110448735.
# [I 2026-06-29 16:21:28,419] Trial 1 finished with value: 13.81509550877377 and parameters: {'n_estimators': 73, 'max_leaf_nodes': 41, 'min_samples_split': 10, 'max_depth': 17}. Best is trial 1 with value: 13.81509550877377.
# [I 2026-06-29 16:21:32,981] Trial 2 finished with value: 11.108702001556154 and parameters: {'n_estimators': 140, 'max_leaf_nodes': 182, 'min_samples_split': 6, 'max_depth': 20}. Best is trial 2 with value: 11.108702001556154.
# [I 2026-06-29 16:21:38,126] Trial 3 finished with value: 20.612124719409394 and parameters: {'n_estimators': 175, 'max_leaf_nodes': 56, 'min_samples_split': 22, 'max_depth': 6}. Best is trial 2 with value: 11.108702001556154.
# [I 2026-06-29 16:21:40,898] Trial 4 finished with value: 31.642615654856304 and parameters: {'n_estimators': 95, 'max_leaf_nodes': 135, 'min_samples_split': 46, 'max_depth': 7}. Best is trial 2 with value: 11.108702001556154.
# [I 2026-06-29 16:21:44,860] Trial 5 finished with value: 23.03332939154877 and parameters: {'n_estimators': 142, 'max_leaf_nodes': 37, 'min_samples_split': 33, 'max_depth': 8}. Best is trial 2 with value: 11.108702001556154.
# [I 2026-06-29 16:21:48,424] Trial 6 finished with value: 20.701956012008075 and parameters: {'n_estimators': 118, 'max_leaf_nodes': 202, 'min_samples_split': 24, 'max_depth': 10}. Best is trial 2 with value: 11.108702001556154.
# [I 2026-06-29 16:21:52,510] Trial 7 finished with value: 31.687188137873196 and parameters: {'n_estimators': 139, 'max_leaf_nodes': 13, 'min_samples_split': 63, 'max_depth': 6}. Best is trial 2 with value: 11.108702001556154.
# [I 2026-06-29 16:21:54,202] Trial 8 finished with value: 31.75239510780205 and parameters: {'n_estimators': 59, 'max_leaf_nodes': 243, 'min_samples_split': 97, 'max_depth': 15}. Best is trial 2 with value: 11.108702001556154.
# [I 2026-06-29 16:21:56,781] Trial 9 finished with value: 31.748653783038137 and parameters: {'n_estimators': 95, 'max_leaf_nodes': 26, 'min_samples_split': 70, 'max_depth': 9}. Best is trial 2 with value: 11.108702001556154.
# [I 2026-06-29 16:22:02,938] Trial 10 finished with value: 10.516063298465514 and parameters: {'n_estimators': 194, 'max_leaf_nodes': 144, 'min_samples_split': 5, 'max_depth': 19}. Best is trial 10 with value: 10.516063298465514.
# [I 2026-06-29 16:22:09,318] Trial 11 finished with value: 11.139974039176131 and parameters: {'n_estimators': 195, 'max_leaf_nodes': 148, 'min_samples_split': 6, 'max_depth': 20}. Best is trial 10 with value: 10.516063298465514.
# [I 2026-06-29 16:22:14,461] Trial 12 finished with value: 10.557649379978706 and parameters: {'n_estimators': 164, 'max_leaf_nodes': 184, 'min_samples_split': 5, 'max_depth': 13}. Best is trial 10 with value: 10.516063298465514.
# [I 2026-06-29 16:22:19,256] Trial 13 finished with value: 29.19987339394861 and parameters: {'n_estimators': 171, 'max_leaf_nodes': 93, 'min_samples_split': 41, 'max_depth': 13}. Best is trial 10 with value: 10.516063298465514.
# [I 2026-06-29 16:22:24,854] Trial 14 finished with value: 20.64540883769571 and parameters: {'n_estimators': 199, 'max_leaf_nodes': 177, 'min_samples_split': 22, 'max_depth': 13}. Best is trial 10 with value: 10.516063298465514.
# [I 2026-06-29 16:22:29,717] Trial 15 finished with value: 21.762574195248625 and parameters: {'n_estimators': 169, 'max_leaf_nodes': 97, 'min_samples_split': 30, 'max_depth': 16}. Best is trial 10 with value: 10.516063298465514.
# [I 2026-06-29 16:22:34,622] Trial 16 finished with value: 17.68919886091358 and parameters: {'n_estimators': 158, 'max_leaf_nodes': 207, 'min_samples_split': 15, 'max_depth': 12}. Best is trial 10 with value: 10.516063298465514.
# [I 2026-06-29 16:22:39,638] Trial 17 finished with value: 31.6664547527444 and parameters: {'n_estimators': 187, 'max_leaf_nodes': 105, 'min_samples_split': 57, 'max_depth': 15}. Best is trial 10 with value: 10.516063298465514.
# [I 2026-06-29 16:22:43,815] Trial 18 finished with value: 31.680917730896965 and parameters: {'n_estimators': 151, 'max_leaf_nodes': 151, 'min_samples_split': 88, 'max_depth': 5}. Best is trial 10 with value: 10.516063298465514.
# [I 2026-06-29 16:22:48,804] Trial 19 finished with value: 27.37487988023792 and parameters: {'n_estimators': 183, 'max_leaf_nodes': 212, 'min_samples_split': 39, 'max_depth': 18}. Best is trial 10 with value: 10.516063298465514.

# %%
#best hyperparameters RF
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'n_estimators': 194, 'max_leaf_nodes': 144, 'min_samples_split': 5, 'max_depth': 19}

# %%
# Treinar modelo final
best_model = RandomForestRegressor(
    n_estimators=study.best_params['n_estimators'],
    max_leaf_nodes=study.best_params['max_leaf_nodes'],
    min_samples_split=study.best_params['min_samples_split'],
    max_depth=study.best_params['max_depth'],
    random_state=42
)

best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 3.5973
# MAE:  2.4639
# MAPE: 0.2972%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()

# %%
# Valores shapĺey
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

# %%
# shap beer plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="dot", show=False)
plt.tight_layout()
plt.show()

# %%
# shap bar plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="bar", show=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ridge

# %%
#function Optuna -- Ridge
def objective(trial):
    # 1. Define hyperparameters to tune
    alpha = trial.suggest_float('alpha', 1e-5, 1e2, log=True)
        
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = Ridge(
            alpha=alpha,
            random_state=42
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna Ridge
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:23:39,068] A new study created in memory with name: no-name-58dcf110-cf3c-4a7e-a6e4-ea76dcb85c9c
# [I 2026-06-29 16:23:39,190] Trial 0 finished with value: 11.15397825114217 and parameters: {'alpha': 0.004185822729546971}. Best is trial 0 with value: 11.15397825114217.
# [I 2026-06-29 16:23:39,276] Trial 1 finished with value: 11.161109716646502 and parameters: {'alpha': 45.18560951024108}. Best is trial 0 with value: 11.15397825114217.
# [I 2026-06-29 16:23:39,364] Trial 2 finished with value: 9.064287111190927 and parameters: {'alpha': 1.330324510152291}. Best is trial 2 with value: 9.064287111190927.
# [I 2026-06-29 16:23:39,450] Trial 3 finished with value: 9.644746643430846 and parameters: {'alpha': 0.1550991398759431}. Best is trial 2 with value: 9.064287111190927.
# [I 2026-06-29 16:23:39,536] Trial 4 finished with value: 12.146778535552786 and parameters: {'alpha': 0.000123631882770522}. Best is trial 2 with value: 9.064287111190927.
# [I 2026-06-29 16:23:39,622] Trial 5 finished with value: 12.14681451677171 and parameters: {'alpha': 0.0001235838277230692}. Best is trial 2 with value: 9.064287111190927.
# [I 2026-06-29 16:23:39,714] Trial 6 finished with value: 12.224698869446998 and parameters: {'alpha': 2.550264850403285e-05}. Best is trial 2 with value: 9.064287111190927.
# [I 2026-06-29 16:23:39,811] Trial 7 finished with value: 9.49543983795345 and parameters: {'alpha': 11.567327199145982}. Best is trial 2 with value: 9.064287111190927.
# [I 2026-06-29 16:23:39,939] Trial 8 finished with value: 9.634730559033132 and parameters: {'alpha': 0.16136341713591323}. Best is trial 2 with value: 9.064287111190927.
# [I 2026-06-29 16:23:40,064] Trial 9 finished with value: 9.175311914364213 and parameters: {'alpha': 0.9047071957568393}. Best is trial 2 with value: 9.064287111190927.
# [I 2026-06-29 16:23:40,153] Trial 10 finished with value: 11.499180359424358 and parameters: {'alpha': 0.0017592692901773263}. Best is trial 2 with value: 9.064287111190927.
# [I 2026-06-29 16:23:40,239] Trial 11 finished with value: 8.958910354087593 and parameters: {'alpha': 2.1960517556813066}. Best is trial 11 with value: 8.958910354087593.
# [I 2026-06-29 16:23:40,326] Trial 12 finished with value: 9.48291165414954 and parameters: {'alpha': 11.30276471683559}. Best is trial 11 with value: 8.958910354087593.
# [I 2026-06-29 16:23:40,416] Trial 13 finished with value: 9.040654007578821 and parameters: {'alpha': 1.4389426114965096}. Best is trial 11 with value: 8.958910354087593.
# [I 2026-06-29 16:23:40,502] Trial 14 finished with value: 8.984177145600933 and parameters: {'alpha': 1.7645874545686617}. Best is trial 11 with value: 8.958910354087593.
# [I 2026-06-29 16:23:40,592] Trial 15 finished with value: 10.9208200305517 and parameters: {'alpha': 0.0074043283503099555}. Best is trial 11 with value: 8.958910354087593.
# [I 2026-06-29 16:23:40,681] Trial 16 finished with value: 9.939459959581528 and parameters: {'alpha': 0.0700734632888759}. Best is trial 11 with value: 8.958910354087593.
# [I 2026-06-29 16:23:40,774] Trial 17 finished with value: 11.687903877304922 and parameters: {'alpha': 61.81553314271539}. Best is trial 11 with value: 8.958910354087593.
# [I 2026-06-29 16:23:40,866] Trial 18 finished with value: 9.009080176827604 and parameters: {'alpha': 3.4678227569852718}. Best is trial 11 with value: 8.958910354087593.
# [I 2026-06-29 16:23:40,956] Trial 19 finished with value: 9.440621288977269 and parameters: {'alpha': 0.3206189270127575}. Best is trial 11 with value: 8.958910354087593.

# %%
#best hyperparameters Ridge
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'alpha': 2.1960517556813066}

# %%
# Treinar modelo final
best_model = Ridge(
    alpha=study.best_params['alpha'],
    random_state=42
)

best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 8.8594
# MAE:  7.0754
# MAPE: 0.8524%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()

# %% [markdown]
# Ao executa o explainer abaixo gerou erro para o algoritmo `Ridge`. InvalidModelError: Model type not yet supported by TreeExplainer: <class 'sklearn.linear_model._ridge.Ridge'>

# %%
# Valores shapĺey
# explainer = shap.TreeExplainer(best_model)
# shap_values = explainer.shap_values(X)

# %% [markdown]
# ## KNN

# %%
#function Optuna -- kNN
def objective(trial):
    # 1. Define hyperparameters to tune
    n_neighbors = trial.suggest_int('n_neighbors', 1, 10)
    weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
    metric = trial.suggest_categorical('metric', ['euclidean', 'manhattan'])
        
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = KNeighborsRegressor(
            n_neighbors=n_neighbors,
            weights=weights,
            metric=metric
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna knn
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:25:43,015] A new study created in memory with name: no-name-4dba85d9-8501-48fa-8779-9d21c5333121
# [I 2026-06-29 16:25:43,135] Trial 0 finished with value: 10.281535087719309 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 0 with value: 10.281535087719309.
# [I 2026-06-29 16:25:43,240] Trial 1 finished with value: 6.170836447064754 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 1 with value: 6.170836447064754.
# [I 2026-06-29 16:25:43,346] Trial 2 finished with value: 5.3191228070175445 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:43,446] Trial 3 finished with value: 6.290803353944559 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:43,589] Trial 4 finished with value: 10.86286496980492 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:43,694] Trial 5 finished with value: 11.179689390161052 and parameters: {'n_neighbors': 8, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:43,816] Trial 6 finished with value: 13.294711779448612 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:43,933] Trial 7 finished with value: 14.7485769980507 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,025] Trial 8 finished with value: 6.91192982456141 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,124] Trial 9 finished with value: 10.681247349286384 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,220] Trial 10 finished with value: 9.913903508771938 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,324] Trial 11 finished with value: 5.589649122807035 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,438] Trial 12 finished with value: 5.58964912280702 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,552] Trial 13 finished with value: 9.913903508771938 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,668] Trial 14 finished with value: 5.3191228070175445 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,763] Trial 15 finished with value: 8.441461988304106 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,862] Trial 16 finished with value: 11.203754385964919 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:44,962] Trial 17 finished with value: 5.3191228070175445 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:45,081] Trial 18 finished with value: 8.441461988304106 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.
# [I 2026-06-29 16:25:45,229] Trial 19 finished with value: 15.89866666666667 and parameters: {'n_neighbors': 10, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.3191228070175445.

# %%
#best hyperparameters knn
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'euclidean'}

# %%
# Treinar modelo final
best_model = KNeighborsRegressor(
    n_neighbors=study.best_params['n_neighbors'],
    weights=study.best_params['weights'],
    metric=study.best_params['metric']
)
best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 0.0000
# MAE:  0.0000
# MAPE: 0.0000%

# %% [markdown]
# ## XGBoost

# %%
#function Optuna -- XGB
def objective(trial):
    # 1. Define hyperparameters to tune
    max_depth = trial.suggest_int('max_depth', 3, 10)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.1)
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    gamma = trial.suggest_float('gamma', 0, 5)
        
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = XGBRegressor(
            max_depth = max_depth,
            learning_rate = learning_rate,
            n_estimators = n_estimators,
            subsample = subsample,
            colsample_bytree = colsample_bytree,
            min_child_weight = min_child_weight,
            gamma = gamma
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna XGB
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:25:58,597] A new study created in memory with name: no-name-606bbc1a-9613-4957-97e1-4b4556383b4b
# [I 2026-06-29 16:26:05,627] Trial 0 finished with value: 8.412339466831149 and parameters: {'max_depth': 5, 'learning_rate': 0.09556428757689246, 'n_estimators': 149, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'min_child_weight': 2, 'gamma': 0.2904180608409973}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:26:13,438] Trial 1 finished with value: 14.969071708813056 and parameters: {'max_depth': 9, 'learning_rate': 0.0641003510568888, 'n_estimators': 145, 'subsample': 0.5102922471479012, 'colsample_bytree': 0.9849549260809971, 'min_child_weight': 9, 'gamma': 1.0616955533913808}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:26:21,617] Trial 2 finished with value: 15.818666949355816 and parameters: {'max_depth': 4, 'learning_rate': 0.026506405886809047, 'n_estimators': 68, 'subsample': 0.762378215816119, 'colsample_bytree': 0.7159725093210578, 'min_child_weight': 3, 'gamma': 3.0592644736118975}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:26:29,454] Trial 3 finished with value: 11.841655701754393 and parameters: {'max_depth': 4, 'learning_rate': 0.03629301836816964, 'n_estimators': 79, 'subsample': 0.728034992108518, 'colsample_bytree': 0.8925879806965068, 'min_child_weight': 2, 'gamma': 2.571172192068058}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:26:37,284] Trial 4 finished with value: 22.65281181469299 and parameters: {'max_depth': 7, 'learning_rate': 0.014180537144799797, 'n_estimators': 126, 'subsample': 0.5852620618436457, 'colsample_bytree': 0.5325257964926398, 'min_child_weight': 10, 'gamma': 4.828160165372797}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:26:40,776] Trial 5 finished with value: 19.423814204701205 and parameters: {'max_depth': 9, 'learning_rate': 0.037415239225603365, 'n_estimators': 28, 'subsample': 0.8421165132560784, 'colsample_bytree': 0.7200762468698007, 'min_child_weight': 2, 'gamma': 2.475884550556351}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:26:44,298] Trial 6 finished with value: 11.384783699972596 and parameters: {'max_depth': 3, 'learning_rate': 0.09183883618709039, 'n_estimators': 59, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'min_child_weight': 6, 'gamma': 2.7335513967163982}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:26:52,276] Trial 7 finished with value: 10.071837222450666 and parameters: {'max_depth': 4, 'learning_rate': 0.09726261649881028, 'n_estimators': 158, 'subsample': 0.9697494707820946, 'colsample_bytree': 0.9474136752138245, 'min_child_weight': 6, 'gamma': 4.609371175115584}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:26:54,033] Trial 8 finished with value: 25.09357331928454 and parameters: {'max_depth': 3, 'learning_rate': 0.027638457617723072, 'n_estimators': 18, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'min_child_weight': 3, 'gamma': 4.143687545759647}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:27:00,217] Trial 9 finished with value: 10.780096071477532 and parameters: {'max_depth': 5, 'learning_rate': 0.03528410587186427, 'n_estimators': 113, 'subsample': 0.5704621124873813, 'colsample_bytree': 0.9010984903770198, 'min_child_weight': 1, 'gamma': 4.9344346830025865}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:27:09,998] Trial 10 finished with value: 9.30326561643367 and parameters: {'max_depth': 7, 'learning_rate': 0.07355202867601571, 'n_estimators': 195, 'subsample': 0.9661451709558936, 'colsample_bytree': 0.5076838686640521, 'min_child_weight': 5, 'gamma': 0.0757211855137844}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:27:19,324] Trial 11 finished with value: 9.18395494962994 and parameters: {'max_depth': 7, 'learning_rate': 0.07536473650671748, 'n_estimators': 200, 'subsample': 0.9968676185612808, 'colsample_bytree': 0.5046138345222255, 'min_child_weight': 5, 'gamma': 0.14281808621478387}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:27:29,336] Trial 12 finished with value: 9.065951291803735 and parameters: {'max_depth': 6, 'learning_rate': 0.08074672937766333, 'n_estimators': 200, 'subsample': 0.886733279737485, 'colsample_bytree': 0.6010807595833223, 'min_child_weight': 5, 'gamma': 0.3172652091957414}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:27:39,868] Trial 13 finished with value: 10.542208573190798 and parameters: {'max_depth': 6, 'learning_rate': 0.08353438346524467, 'n_estimators': 166, 'subsample': 0.8793269933569663, 'colsample_bytree': 0.6101112185672232, 'min_child_weight': 8, 'gamma': 1.1356950582543925}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:27:53,656] Trial 14 finished with value: 9.347829589843759 and parameters: {'max_depth': 6, 'learning_rate': 0.05496943016780943, 'n_estimators': 176, 'subsample': 0.8865371275301077, 'colsample_bytree': 0.8095839387020464, 'min_child_weight': 4, 'gamma': 0.9942582283485234}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:28:00,703] Trial 15 finished with value: 10.507889125890907 and parameters: {'max_depth': 8, 'learning_rate': 0.09920062188910214, 'n_estimators': 133, 'subsample': 0.749179442894701, 'colsample_bytree': 0.5979644942759227, 'min_child_weight': 7, 'gamma': 1.600993585974407}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:28:07,230] Trial 16 finished with value: 8.800391781455604 and parameters: {'max_depth': 5, 'learning_rate': 0.0839327480946421, 'n_estimators': 96, 'subsample': 0.805845496366991, 'colsample_bytree': 0.7947992509228796, 'min_child_weight': 1, 'gamma': 0.48098547500273026}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:28:13,756] Trial 17 finished with value: 9.5606363075658 and parameters: {'max_depth': 5, 'learning_rate': 0.060473488892098, 'n_estimators': 95, 'subsample': 0.6710472515227898, 'colsample_bytree': 0.7997509191284597, 'min_child_weight': 1, 'gamma': 1.5738742956100042}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:28:20,247] Trial 18 finished with value: 9.510051012541128 and parameters: {'max_depth': 5, 'learning_rate': 0.0852465533299212, 'n_estimators': 101, 'subsample': 0.791412280667512, 'colsample_bytree': 0.8285726521637807, 'min_child_weight': 3, 'gamma': 0.5339803857544652}. Best is trial 0 with value: 8.412339466831149.
# [I 2026-06-29 16:28:23,848] Trial 19 finished with value: 14.087408682839916 and parameters: {'max_depth': 5, 'learning_rate': 0.0493295804270662, 'n_estimators': 43, 'subsample': 0.6798654439008402, 'colsample_bytree': 0.7696363894573159, 'min_child_weight': 1, 'gamma': 2.083093661844673}. Best is trial 0 with value: 8.412339466831149.

# %%
#best hyperparameters Ridge
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'max_depth': 5, 'learning_rate': 0.09556428757689246, 'n_estimators': 149, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'min_child_weight': 2, 'gamma': 0.2904180608409973}

# %%
# Treinar modelo final
best_model = XGBRegressor(
    max_depth=study.best_params['max_depth'],
    learning_rate=study.best_params['learning_rate'],
    n_estimators=study.best_params['n_estimators'],
    subsample=study.best_params['subsample'],
    alpcolsample_bytreeha=study.best_params['colsample_bytree'],
    min_child_weight=study.best_params['min_child_weight'],
    gamma=study.best_params['gamma'],
    random_state=42
)

best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 0.2753
# MAE:  0.2031
# MAPE: 0.0244%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()

# %%
# Valores shapĺey
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

# %%
# shap beer plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="dot", show=False)
plt.tight_layout()
plt.show()

# %%
# shap bar plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="bar", show=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## VotinRegressor

# %%
#function Optuna -- Voting Regressor
def objective(trial):
    # 1. Define hyperparameters to tune
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 200)
    rf_max_leaf_nodes = trial.suggest_int('rf_max_leaf_nodes', 2, 256)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 5, 100)
    rf_max_depth = trial.suggest_int('rf_max_depth', 5, 20, log=True)
    
    ridge_alpha = trial.suggest_float('ridge_alpha', 0.1, 100)
    
    knn_neighbors = trial.suggest_int('knn_neighbors', 1, 10)
    knn_weights = trial.suggest_categorical('knn_weights', ['uniform', 'distance'])
    
    xgb_max_depth = trial.suggest_int('xgb_max_depth', 3, 10)
    xgb_learning_rate = trial.suggest_float('xgb_learning_rate', 0.01, 0.3)
    xgb_n_estimators = trial.suggest_int('xgb_n_estimators', 50, 200)
    
    # 2. Expanding window parameters
    initial_train_size = 10
    step_size = 1
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        rf_model = RandomForestRegressor(
            n_estimators=rf_n_estimators,
            max_leaf_nodes=rf_max_leaf_nodes,
            min_samples_split=rf_min_samples_split,
            max_depth=rf_max_depth,
            random_state=42
        )
        
        ridge_model = Ridge(alpha=ridge_alpha)
        
        knn_model = KNeighborsRegressor(
            n_neighbors=knn_neighbors,
            weights=knn_weights
        )
        
        xgb_model = XGBRegressor(
            max_depth=xgb_max_depth,
            learning_rate=xgb_learning_rate,
            n_estimators=xgb_n_estimators,
            random_state=42
        )
        
        voting_model = VotingRegressor(
            estimators=[('rf', rf_model), ('ridge', ridge_model), ('knn', knn_model), ('xgb', xgb_model)]
        )
        
        voting_model.fit(X_train, y_train)
        preds = voting_model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = np.sqrt(mean_squared_error(y_val, preds))
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna Voting Regressor
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:28:44,400] A new study created in memory with name: no-name-a7fc7835-307b-44dc-abf3-ceeecc4694e8
# [I 2026-06-29 16:28:53,152] Trial 0 finished with value: 12.636212875482109 and parameters: {'rf_n_estimators': 106, 'rf_max_leaf_nodes': 244, 'rf_min_samples_split': 75, 'rf_max_depth': 11, 'ridge_alpha': 15.686262180199408, 'knn_neighbors': 2, 'knn_weights': 'distance', 'xgb_max_depth': 7, 'xgb_learning_rate': 0.21534104756085318, 'xgb_n_estimators': 53}. Best is trial 0 with value: 12.636212875482109.
# [I 2026-06-29 16:29:04,771] Trial 1 finished with value: 11.041879070099146 and parameters: {'rf_n_estimators': 196, 'rf_max_leaf_nodes': 214, 'rf_min_samples_split': 25, 'rf_max_depth': 6, 'ridge_alpha': 18.42211053435804, 'knn_neighbors': 4, 'knn_weights': 'uniform', 'xgb_max_depth': 5, 'xgb_learning_rate': 0.18743733946949004, 'xgb_n_estimators': 71}. Best is trial 1 with value: 11.041879070099146.
# [I 2026-06-29 16:29:17,904] Trial 2 finished with value: 14.697234849504513 and parameters: {'rf_n_estimators': 94, 'rf_max_leaf_nodes': 95, 'rf_min_samples_split': 48, 'rf_max_depth': 15, 'ridge_alpha': 20.04741083762014, 'knn_neighbors': 6, 'knn_weights': 'uniform', 'xgb_max_depth': 7, 'xgb_learning_rate': 0.059451995869314544, 'xgb_n_estimators': 59}. Best is trial 1 with value: 11.041879070099146.
# [I 2026-06-29 16:29:41,921] Trial 3 finished with value: 14.626777771331405 and parameters: {'rf_n_estimators': 193, 'rf_max_leaf_nodes': 248, 'rf_min_samples_split': 82, 'rf_max_depth': 7, 'ridge_alpha': 9.857444189237748, 'knn_neighbors': 7, 'knn_weights': 'uniform', 'xgb_max_depth': 6, 'xgb_learning_rate': 0.019972671123413333, 'xgb_n_estimators': 187}. Best is trial 1 with value: 11.041879070099146.
# [I 2026-06-29 16:29:52,510] Trial 4 finished with value: 11.554832872399148 and parameters: {'rf_n_estimators': 89, 'rf_max_leaf_nodes': 170, 'rf_min_samples_split': 34, 'rf_max_depth': 10, 'ridge_alpha': 54.71635690639364, 'knn_neighbors': 2, 'knn_weights': 'uniform', 'xgb_max_depth': 10, 'xgb_learning_rate': 0.26949993162401814, 'xgb_n_estimators': 140}. Best is trial 1 with value: 11.041879070099146.
# [I 2026-06-29 16:30:09,334] Trial 5 finished with value: 11.011834264478157 and parameters: {'rf_n_estimators': 189, 'rf_max_leaf_nodes': 24, 'rf_min_samples_split': 23, 'rf_max_depth': 5, 'ridge_alpha': 32.60050004325011, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 5, 'xgb_learning_rate': 0.09147100780934041, 'xgb_n_estimators': 131}. Best is trial 5 with value: 11.011834264478157.
# [I 2026-06-29 16:30:21,638] Trial 6 finished with value: 10.12572877933113 and parameters: {'rf_n_estimators': 71, 'rf_max_leaf_nodes': 206, 'rf_min_samples_split': 12, 'rf_max_depth': 20, 'ridge_alpha': 77.24725245273608, 'knn_neighbors': 2, 'knn_weights': 'distance', 'xgb_max_depth': 8, 'xgb_learning_rate': 0.2214120787318863, 'xgb_n_estimators': 166}. Best is trial 6 with value: 10.12572877933113.
# [I 2026-06-29 16:30:32,658] Trial 7 finished with value: 10.944277826268763 and parameters: {'rf_n_estimators': 61, 'rf_max_leaf_nodes': 93, 'rf_min_samples_split': 16, 'rf_max_depth': 17, 'ridge_alpha': 62.36748287007304, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 5, 'xgb_learning_rate': 0.22158579171803858, 'xgb_n_estimators': 146}. Best is trial 6 with value: 10.12572877933113.
# [I 2026-06-29 16:30:45,915] Trial 8 finished with value: 11.896042949876815 and parameters: {'rf_n_estimators': 183, 'rf_max_leaf_nodes': 122, 'rf_min_samples_split': 16, 'rf_max_depth': 13, 'ridge_alpha': 76.10242635682805, 'knn_neighbors': 6, 'knn_weights': 'uniform', 'xgb_max_depth': 7, 'xgb_learning_rate': 0.1339868953239794, 'xgb_n_estimators': 53}. Best is trial 6 with value: 10.12572877933113.
# [I 2026-06-29 16:30:53,692] Trial 9 finished with value: 15.312349085672082 and parameters: {'rf_n_estimators': 66, 'rf_max_leaf_nodes': 10, 'rf_min_samples_split': 66, 'rf_max_depth': 7, 'ridge_alpha': 50.90621204735381, 'knn_neighbors': 10, 'knn_weights': 'distance', 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0763514679925705, 'xgb_n_estimators': 61}. Best is trial 6 with value: 10.12572877933113.
# [I 2026-06-29 16:31:09,127] Trial 10 finished with value: 13.550411852714763 and parameters: {'rf_n_estimators': 152, 'rf_max_leaf_nodes': 180, 'rf_min_samples_split': 98, 'rf_max_depth': 19, 'ridge_alpha': 97.93061021066814, 'knn_neighbors': 1, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.2875458119633852, 'xgb_n_estimators': 199}. Best is trial 6 with value: 10.12572877933113.
# [I 2026-06-29 16:31:22,719] Trial 11 finished with value: 9.587927464631678 and parameters: {'rf_n_estimators': 51, 'rf_max_leaf_nodes': 76, 'rf_min_samples_split': 6, 'rf_max_depth': 20, 'ridge_alpha': 73.26037517183372, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.2231377497934563, 'xgb_n_estimators': 165}. Best is trial 11 with value: 9.587927464631678.
# [I 2026-06-29 16:31:34,066] Trial 12 finished with value: 9.393437582518871 and parameters: {'rf_n_estimators': 59, 'rf_max_leaf_nodes': 63, 'rf_min_samples_split': 6, 'rf_max_depth': 19, 'ridge_alpha': 82.4472580785703, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.15912464772022475, 'xgb_n_estimators': 167}. Best is trial 12 with value: 9.393437582518871.
# [I 2026-06-29 16:31:42,537] Trial 13 finished with value: 10.550578042312548 and parameters: {'rf_n_estimators': 50, 'rf_max_leaf_nodes': 55, 'rf_min_samples_split': 7, 'rf_max_depth': 13, 'ridge_alpha': 99.52649706783617, 'knn_neighbors': 8, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.14401327993632712, 'xgb_n_estimators': 104}. Best is trial 12 with value: 9.393437582518871.
# [I 2026-06-29 16:32:00,465] Trial 14 finished with value: 13.119585379153072 and parameters: {'rf_n_estimators': 143, 'rf_max_leaf_nodes': 53, 'rf_min_samples_split': 40, 'rf_max_depth': 15, 'ridge_alpha': 80.22109056100906, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.18110631970258684, 'xgb_n_estimators': 167}. Best is trial 12 with value: 9.393437582518871.
# [I 2026-06-29 16:32:11,089] Trial 15 finished with value: 9.237252262619045 and parameters: {'rf_n_estimators': 113, 'rf_max_leaf_nodes': 68, 'rf_min_samples_split': 5, 'rf_max_depth': 20, 'ridge_alpha': 67.42069496418958, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.2537557856012104, 'xgb_n_estimators': 164}. Best is trial 15 with value: 9.237252262619045.
# [I 2026-06-29 16:32:20,493] Trial 16 finished with value: 11.210455569915897 and parameters: {'rf_n_estimators': 124, 'rf_max_leaf_nodes': 138, 'rf_min_samples_split': 31, 'rf_max_depth': 16, 'ridge_alpha': 87.0757373150788, 'knn_neighbors': 1, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.2533391110130563, 'xgb_n_estimators': 98}. Best is trial 15 with value: 9.237252262619045.
# [I 2026-06-29 16:32:34,093] Trial 17 finished with value: 13.263204132622075 and parameters: {'rf_n_estimators': 127, 'rf_max_leaf_nodes': 40, 'rf_min_samples_split': 59, 'rf_max_depth': 12, 'ridge_alpha': 37.694001449879096, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.12451682870043082, 'xgb_n_estimators': 181}. Best is trial 15 with value: 9.237252262619045.
# [I 2026-06-29 16:32:42,741] Trial 18 finished with value: 14.12603801970956 and parameters: {'rf_n_estimators': 84, 'rf_max_leaf_nodes': 125, 'rf_min_samples_split': 46, 'rf_max_depth': 9, 'ridge_alpha': 65.3232291569916, 'knn_neighbors': 5, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.29958988760163924, 'xgb_n_estimators': 115}. Best is trial 15 with value: 9.237252262619045.
# [I 2026-06-29 16:32:57,356] Trial 19 finished with value: 10.878699182982231 and parameters: {'rf_n_estimators': 169, 'rf_max_leaf_nodes': 2, 'rf_min_samples_split': 24, 'rf_max_depth': 9, 'ridge_alpha': 40.476458548192646, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 6, 'xgb_learning_rate': 0.18326755312991164, 'xgb_n_estimators': 155}. Best is trial 15 with value: 9.237252262619045.

# %%
#best hyperparameters Voting Regressor
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'rf_n_estimators': 113, 'rf_max_leaf_nodes': 68, 'rf_min_samples_split': 5, 'rf_max_depth': 20, 'ridge_alpha': 67.42069496418958, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.2537557856012104, 'xgb_n_estimators': 164}

# %%
# Treinar modelo final
best_model = VotingRegressor(
    estimators=[
        ('rf', RandomForestRegressor(
            n_estimators=study.best_params['rf_n_estimators'],
            max_leaf_nodes=study.best_params['rf_max_leaf_nodes'],
            min_samples_split=study.best_params['rf_min_samples_split'],
            max_depth=study.best_params['rf_max_depth'],
            random_state=42
        )),
        ('ridge', Ridge(alpha=study.best_params['ridge_alpha'])),
        ('knn', KNeighborsRegressor(
            n_neighbors=study.best_params['knn_neighbors'],
            weights=study.best_params['knn_weights']
        )),
        ('xgb', XGBRegressor(
            max_depth=study.best_params['xgb_max_depth'],
            learning_rate=study.best_params['xgb_learning_rate'],
            n_estimators=study.best_params['xgb_n_estimators'],
            random_state=42
        ))
    ]
)
 
best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 3.2789
# MAE:  2.6653
# MAPE: 0.3217%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()
