# %% [markdown]
# ## Bibliotecas

# %%
#import packages
import pandas as pd
import numpy as np
import os
import warnings
import optuna
from sklearn.metrics import root_mean_squared_error, mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor, VotingRegressor
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
import shap
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# ## Configurações

# %%
# Definir diretório
os.chdir('/home/joao/Área de Trabalho/tese')

# Evitar avisos
warnings.filterwarnings('ignore')

# %%
#load dataset
df = pd.read_excel('df_conjunto_goiania.xlsx')

# %%
#rename columns
df = df.rename(columns={
    'semana':'week',
    'cesta_dieese':'dieese_basket',
    'carne':'meat',
    'leite':'milk',
    'feijao':'bean',
    'arroz':'rice',
    'farinha':'flour',
    'batata':'potato',
    'tomate':'tomato',
    'pao':'bread',
    'cafe':'coffee',
    'acucar':'sugar',
    'oleo':'lard/oil',
    'manteiga':'butter',
    'cesta_online':'online'
})

# %%
df.columns
# Out:
# Index(['week', 'dieese_basket', 'meat', 'milk', 'bean', 'rice', 'flour',
#        'potato', 'tomato', 'bread', 'coffee', 'banana', 'sugar', 'lard/oil',
#        'butter', 'online'],
#       dtype='object')

# %%
#create lagged dataset
k = 1 #number of lags
y_lag = df[['week','dieese_basket']][k:]
x_lag = df.copy()
x_lag = x_lag.drop(['week','dieese_basket'], axis=1)
x_lag = x_lag[:len(df)-k]
y_lag = y_lag.reset_index(drop=True)
x_lag = x_lag.reset_index(drop=True)
df_lag = pd.concat([y_lag,x_lag], axis=1)

# %%
#set X and y
X = df_lag.copy()
X = X.drop(['week','dieese_basket','online'], axis=1)
y = df_lag['dieese_basket']

# %%
def calculate_mape(y_true, y_pred):
    mask = y_true != 0
    if mask.sum() == 0:
        return 0
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

# %% [markdown]
# ## Random forest

# %%
#function Optuna -- RF
def objective(trial):
    # 1. Define hyperparameters to tune
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 2, 256)
    min_samples_split = trial.suggest_int('min_samples_split', 5, 100)
    max_depth = trial.suggest_int('max_depth', 5, 20, log=True)
    
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = RandomForestRegressor(
            n_estimators=n_estimators,
            max_leaf_nodes=max_leaf_nodes,
            min_samples_split=min_samples_split,
            max_depth=max_depth,
            random_state=42
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna RF
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:56:47,747] A new study created in memory with name: no-name-bb5dd401-0949-42d7-a699-02fbd0ec7112
# [I 2026-06-29 16:56:50,940] Trial 0 finished with value: 28.180446179035403 and parameters: {'n_estimators': 106, 'max_leaf_nodes': 244, 'min_samples_split': 75, 'max_depth': 11}. Best is trial 0 with value: 28.180446179035403.
# [I 2026-06-29 16:56:53,226] Trial 1 finished with value: 11.444796995692405 and parameters: {'n_estimators': 73, 'max_leaf_nodes': 41, 'min_samples_split': 10, 'max_depth': 17}. Best is trial 1 with value: 11.444796995692405.
# [I 2026-06-29 16:56:57,675] Trial 2 finished with value: 9.60068233460749 and parameters: {'n_estimators': 140, 'max_leaf_nodes': 182, 'min_samples_split': 6, 'max_depth': 20}. Best is trial 2 with value: 9.60068233460749.
# [I 2026-06-29 16:57:02,668] Trial 3 finished with value: 16.368759906584366 and parameters: {'n_estimators': 175, 'max_leaf_nodes': 56, 'min_samples_split': 22, 'max_depth': 6}. Best is trial 2 with value: 9.60068233460749.
# [I 2026-06-29 16:57:05,211] Trial 4 finished with value: 28.161624946115975 and parameters: {'n_estimators': 95, 'max_leaf_nodes': 135, 'min_samples_split': 46, 'max_depth': 7}. Best is trial 2 with value: 9.60068233460749.
# [I 2026-06-29 16:57:09,865] Trial 5 finished with value: 20.18357985004319 and parameters: {'n_estimators': 142, 'max_leaf_nodes': 37, 'min_samples_split': 33, 'max_depth': 8}. Best is trial 2 with value: 9.60068233460749.
# [I 2026-06-29 16:57:13,391] Trial 6 finished with value: 16.051264215478106 and parameters: {'n_estimators': 118, 'max_leaf_nodes': 202, 'min_samples_split': 24, 'max_depth': 10}. Best is trial 2 with value: 9.60068233460749.
# [I 2026-06-29 16:57:17,246] Trial 7 finished with value: 28.145571751108722 and parameters: {'n_estimators': 139, 'max_leaf_nodes': 13, 'min_samples_split': 63, 'max_depth': 6}. Best is trial 2 with value: 9.60068233460749.
# [I 2026-06-29 16:57:18,998] Trial 8 finished with value: 28.276713584552134 and parameters: {'n_estimators': 59, 'max_leaf_nodes': 243, 'min_samples_split': 97, 'max_depth': 15}. Best is trial 2 with value: 9.60068233460749.
# [I 2026-06-29 16:57:21,942] Trial 9 finished with value: 28.232977052340917 and parameters: {'n_estimators': 95, 'max_leaf_nodes': 26, 'min_samples_split': 70, 'max_depth': 9}. Best is trial 2 with value: 9.60068233460749.
# [I 2026-06-29 16:57:28,596] Trial 10 finished with value: 9.296639400086892 and parameters: {'n_estimators': 194, 'max_leaf_nodes': 144, 'min_samples_split': 5, 'max_depth': 19}. Best is trial 10 with value: 9.296639400086892.
# [I 2026-06-29 16:57:34,729] Trial 11 finished with value: 9.52227707409364 and parameters: {'n_estimators': 195, 'max_leaf_nodes': 148, 'min_samples_split': 6, 'max_depth': 20}. Best is trial 10 with value: 9.296639400086892.
# [I 2026-06-29 16:57:39,879] Trial 12 finished with value: 26.962229594975074 and parameters: {'n_estimators': 196, 'max_leaf_nodes': 111, 'min_samples_split': 42, 'max_depth': 13}. Best is trial 10 with value: 9.296639400086892.
# [I 2026-06-29 16:57:45,438] Trial 13 finished with value: 14.792642689020061 and parameters: {'n_estimators': 196, 'max_leaf_nodes': 123, 'min_samples_split': 18, 'max_depth': 20}. Best is trial 10 with value: 9.296639400086892.
# [I 2026-06-29 16:57:51,339] Trial 14 finished with value: 9.284501129517723 and parameters: {'n_estimators': 173, 'max_leaf_nodes': 170, 'min_samples_split': 5, 'max_depth': 14}. Best is trial 14 with value: 9.284501129517723.
# [I 2026-06-29 16:57:56,046] Trial 15 finished with value: 17.723848631574523 and parameters: {'n_estimators': 169, 'max_leaf_nodes': 84, 'min_samples_split': 30, 'max_depth': 13}. Best is trial 14 with value: 9.284501129517723.
# [I 2026-06-29 16:58:00,740] Trial 16 finished with value: 28.117644918738744 and parameters: {'n_estimators': 166, 'max_leaf_nodes': 186, 'min_samples_split': 54, 'max_depth': 16}. Best is trial 14 with value: 9.284501129517723.
# [I 2026-06-29 16:58:04,991] Trial 17 finished with value: 28.14519368463777 and parameters: {'n_estimators': 160, 'max_leaf_nodes': 162, 'min_samples_split': 88, 'max_depth': 13}. Best is trial 14 with value: 9.284501129517723.
# [I 2026-06-29 16:58:10,312] Trial 18 finished with value: 14.118636778560589 and parameters: {'n_estimators': 179, 'max_leaf_nodes': 92, 'min_samples_split': 17, 'max_depth': 16}. Best is trial 14 with value: 9.284501129517723.
# [I 2026-06-29 16:58:14,523] Trial 19 finished with value: 23.301142177040454 and parameters: {'n_estimators': 152, 'max_leaf_nodes': 203, 'min_samples_split': 37, 'max_depth': 5}. Best is trial 14 with value: 9.284501129517723.

# %%
#best hyperparameters RF
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'n_estimators': 173, 'max_leaf_nodes': 170, 'min_samples_split': 5, 'max_depth': 14}

# %%
# Treinar modelo final
best_model = RandomForestRegressor(
    n_estimators=study.best_params['n_estimators'],
    max_leaf_nodes=study.best_params['max_leaf_nodes'],
    min_samples_split=study.best_params['min_samples_split'],
    max_depth=study.best_params['max_depth'],
    random_state=42
)

best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 2.8985
# MAE:  2.0196
# MAPE: 0.2836%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()

# %%
# Valores shapĺey
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

# %%
# shap beer plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="dot", show=False)
plt.tight_layout()
plt.show()

# %%
# shap bar plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="bar", show=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ridge

# %%
#function Optuna -- Ridge
def objective(trial):
    # 1. Define hyperparameters to tune
    alpha = trial.suggest_float('alpha', 1e-5, 1e2, log=True)
        
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = Ridge(
            alpha=alpha,
            random_state=42
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna Ridge
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:58:15,105] A new study created in memory with name: no-name-ddad74d7-2b0f-450f-9649-7a5181b3a1f6
# [I 2026-06-29 16:58:15,201] Trial 0 finished with value: 9.689956315876536 and parameters: {'alpha': 0.004185822729546971}. Best is trial 0 with value: 9.689956315876536.
# [I 2026-06-29 16:58:15,284] Trial 1 finished with value: 10.243134722730815 and parameters: {'alpha': 45.18560951024108}. Best is trial 0 with value: 9.689956315876536.
# [I 2026-06-29 16:58:15,365] Trial 2 finished with value: 8.098832375175167 and parameters: {'alpha': 1.330324510152291}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:15,451] Trial 3 finished with value: 8.748270438729636 and parameters: {'alpha': 0.1550991398759431}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:15,531] Trial 4 finished with value: 9.836941823647939 and parameters: {'alpha': 0.000123631882770522}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:15,636] Trial 5 finished with value: 9.83694601279904 and parameters: {'alpha': 0.0001235838277230692}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:15,733] Trial 6 finished with value: 9.84606206656309 and parameters: {'alpha': 2.550264850403285e-05}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:15,814] Trial 7 finished with value: 8.829179450135847 and parameters: {'alpha': 11.567327199145982}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:15,896] Trial 8 finished with value: 8.729377476037955 and parameters: {'alpha': 0.16136341713591323}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:15,987] Trial 9 finished with value: 8.11846236196975 and parameters: {'alpha': 0.9047071957568393}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:16,070] Trial 10 finished with value: 9.7560907806731 and parameters: {'alpha': 0.0017592692901773263}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:16,155] Trial 11 finished with value: 8.134517233679555 and parameters: {'alpha': 2.1960517556813066}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:16,237] Trial 12 finished with value: 8.165131074065501 and parameters: {'alpha': 0.7461473888517809}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:16,322] Trial 13 finished with value: 9.433223498980855 and parameters: {'alpha': 0.020796413429669477}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:16,428] Trial 14 finished with value: 8.332380409885051 and parameters: {'alpha': 4.583445204728526}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:16,640] Trial 15 finished with value: 8.298931085836116 and parameters: {'alpha': 0.48160892556125723}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:16,748] Trial 16 finished with value: 10.481555946907394 and parameters: {'alpha': 54.840636979585796}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:16,837] Trial 17 finished with value: 9.435768248778672 and parameters: {'alpha': 0.02057207806813223}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:16,930] Trial 18 finished with value: 8.49344942886515 and parameters: {'alpha': 7.000367327846411}. Best is trial 2 with value: 8.098832375175167.
# [I 2026-06-29 16:58:17,026] Trial 19 finished with value: 9.066960204515322 and parameters: {'alpha': 0.07277893660338369}. Best is trial 2 with value: 8.098832375175167.

# %%
#best hyperparameters Ridge
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'alpha': 1.330324510152291}

# %%
# Treinar modelo final
best_model = Ridge(
    alpha=study.best_params['alpha'],
    random_state=42
)

best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 7.4834
# MAE:  5.9131
# MAPE: 0.8287%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()

# %% [markdown]
# Ao executa o explainer abaixo gerou erro para o algoritmo `Ridge`. InvalidModelError: Model type not yet supported by TreeExplainer: <class 'sklearn.linear_model._ridge.Ridge'>

# %%
# Valores shapĺey
# explainer = shap.TreeExplainer(best_model)
# shap_values = explainer.shap_values(X)

# %% [markdown]
# ## KNN

# %%
#function Optuna -- kNN
def objective(trial):
    # 1. Define hyperparameters to tune
    n_neighbors = trial.suggest_int('n_neighbors', 1, 10)
    weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
    metric = trial.suggest_categorical('metric', ['euclidean', 'manhattan'])
        
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = KNeighborsRegressor(
            n_neighbors=n_neighbors,
            weights=weights,
            metric=metric
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna knn
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:58:17,222] A new study created in memory with name: no-name-5efbaa92-63ed-4fda-a9cf-2fb3c7a8d8f8
# [I 2026-06-29 16:58:17,332] Trial 0 finished with value: 9.81324561403506 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 0 with value: 9.81324561403506.
# [I 2026-06-29 16:58:17,426] Trial 1 finished with value: 6.113125038233622 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 1 with value: 6.113125038233622.
# [I 2026-06-29 16:58:17,585] Trial 2 finished with value: 3.7357894736842034 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 3.7357894736842034.
# [I 2026-06-29 16:58:17,669] Trial 3 finished with value: 6.265384406858687 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 2 with value: 3.7357894736842034.
# [I 2026-06-29 16:58:17,791] Trial 4 finished with value: 10.642812577906758 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 2 with value: 3.7357894736842034.
# [I 2026-06-29 16:58:17,882] Trial 5 finished with value: 10.887723585568713 and parameters: {'n_neighbors': 8, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 2 with value: 3.7357894736842034.
# [I 2026-06-29 16:58:17,970] Trial 6 finished with value: 12.455814536340823 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 2 with value: 3.7357894736842034.
# [I 2026-06-29 16:58:18,060] Trial 7 finished with value: 13.436023391812848 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 3.7357894736842034.
# [I 2026-06-29 16:58:18,148] Trial 8 finished with value: 6.583947368421033 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 3.7357894736842034.
# [I 2026-06-29 16:58:18,281] Trial 9 finished with value: 10.393321205657202 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 2 with value: 3.7357894736842034.
# [I 2026-06-29 16:58:18,387] Trial 10 finished with value: 9.796622807017517 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 2 with value: 3.7357894736842034.
# [I 2026-06-29 16:58:18,485] Trial 11 finished with value: 3.6143859649122825 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 11 with value: 3.6143859649122825.
# [I 2026-06-29 16:58:18,574] Trial 12 finished with value: 3.6143859649122745 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 3.6143859649122745.
# [I 2026-06-29 16:58:18,666] Trial 13 finished with value: 8.593021892171798 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 12 with value: 3.6143859649122745.
# [I 2026-06-29 16:58:18,770] Trial 14 finished with value: 3.6143859649122745 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 3.6143859649122745.
# [I 2026-06-29 16:58:18,856] Trial 15 finished with value: 8.696842105263135 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 3.6143859649122745.
# [I 2026-06-29 16:58:18,949] Trial 16 finished with value: 10.926561403508744 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 3.6143859649122745.
# [I 2026-06-29 16:58:19,035] Trial 17 finished with value: 3.6143859649122745 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 3.6143859649122745.
# [I 2026-06-29 16:58:19,125] Trial 18 finished with value: 8.696842105263135 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 3.6143859649122745.
# [I 2026-06-29 16:58:19,227] Trial 19 finished with value: 14.214175438596476 and parameters: {'n_neighbors': 10, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 3.6143859649122745.

# %%
#best hyperparameters knn
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan'}

# %%
# Treinar modelo final
best_model = KNeighborsRegressor(
    n_neighbors=study.best_params['n_neighbors'],
    weights=study.best_params['weights'],
    metric=study.best_params['metric']
)
best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 0.0000
# MAE:  0.0000
# MAPE: 0.0000%

# %% [markdown]
# ## XGBoost

# %%
#function Optuna -- XGB
def objective(trial):
    # 1. Define hyperparameters to tune
    max_depth = trial.suggest_int('max_depth', 3, 10)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.1)
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    gamma = trial.suggest_float('gamma', 0, 5)
        
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = XGBRegressor(
            max_depth = max_depth,
            learning_rate = learning_rate,
            n_estimators = n_estimators,
            subsample = subsample,
            colsample_bytree = colsample_bytree,
            min_child_weight = min_child_weight,
            gamma = gamma
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna XGB
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:58:19,281] A new study created in memory with name: no-name-e95521b8-c722-4b41-acfe-f4eb1d6642fc
# [I 2026-06-29 16:58:28,864] Trial 0 finished with value: 7.974171163993951 and parameters: {'max_depth': 5, 'learning_rate': 0.09556428757689246, 'n_estimators': 149, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'min_child_weight': 2, 'gamma': 0.2904180608409973}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:58:35,282] Trial 1 finished with value: 13.59972938939143 and parameters: {'max_depth': 9, 'learning_rate': 0.0641003510568888, 'n_estimators': 145, 'subsample': 0.5102922471479012, 'colsample_bytree': 0.9849549260809971, 'min_child_weight': 9, 'gamma': 1.0616955533913808}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:58:39,712] Trial 2 finished with value: 13.207595086348666 and parameters: {'max_depth': 4, 'learning_rate': 0.026506405886809047, 'n_estimators': 68, 'subsample': 0.762378215816119, 'colsample_bytree': 0.7159725093210578, 'min_child_weight': 3, 'gamma': 3.0592644736118975}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:58:45,025] Trial 3 finished with value: 10.25690982216281 and parameters: {'max_depth': 4, 'learning_rate': 0.03629301836816964, 'n_estimators': 79, 'subsample': 0.728034992108518, 'colsample_bytree': 0.8925879806965068, 'min_child_weight': 2, 'gamma': 2.571172192068058}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:58:49,948] Trial 4 finished with value: 19.463860291598124 and parameters: {'max_depth': 7, 'learning_rate': 0.014180537144799797, 'n_estimators': 126, 'subsample': 0.5852620618436457, 'colsample_bytree': 0.5325257964926398, 'min_child_weight': 10, 'gamma': 4.828160165372797}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:58:52,204] Trial 5 finished with value: 16.531237750137045 and parameters: {'max_depth': 9, 'learning_rate': 0.037415239225603365, 'n_estimators': 28, 'subsample': 0.8421165132560784, 'colsample_bytree': 0.7200762468698007, 'min_child_weight': 2, 'gamma': 2.475884550556351}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:58:55,138] Trial 6 finished with value: 10.437995691132102 and parameters: {'max_depth': 3, 'learning_rate': 0.09183883618709039, 'n_estimators': 59, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'min_child_weight': 6, 'gamma': 2.7335513967163982}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:59:00,631] Trial 7 finished with value: 10.048341214364012 and parameters: {'max_depth': 4, 'learning_rate': 0.09726261649881028, 'n_estimators': 158, 'subsample': 0.9697494707820946, 'colsample_bytree': 0.9474136752138245, 'min_child_weight': 6, 'gamma': 4.609371175115584}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:59:02,344] Trial 8 finished with value: 21.943122258771915 and parameters: {'max_depth': 3, 'learning_rate': 0.027638457617723072, 'n_estimators': 18, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'min_child_weight': 3, 'gamma': 4.143687545759647}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:59:08,301] Trial 9 finished with value: 9.210294810512586 and parameters: {'max_depth': 5, 'learning_rate': 0.03528410587186427, 'n_estimators': 113, 'subsample': 0.5704621124873813, 'colsample_bytree': 0.9010984903770198, 'min_child_weight': 1, 'gamma': 4.9344346830025865}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:59:18,276] Trial 10 finished with value: 8.553874083401839 and parameters: {'max_depth': 7, 'learning_rate': 0.07355202867601571, 'n_estimators': 195, 'subsample': 0.9661451709558936, 'colsample_bytree': 0.5076838686640521, 'min_child_weight': 5, 'gamma': 0.0757211855137844}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:59:27,123] Trial 11 finished with value: 8.68537901761237 and parameters: {'max_depth': 7, 'learning_rate': 0.07536473650671748, 'n_estimators': 200, 'subsample': 0.9968676185612808, 'colsample_bytree': 0.5046138345222255, 'min_child_weight': 5, 'gamma': 0.14281808621478387}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:59:35,915] Trial 12 finished with value: 8.704686771861269 and parameters: {'max_depth': 6, 'learning_rate': 0.08025861634748394, 'n_estimators': 200, 'subsample': 0.8922867929837619, 'colsample_bytree': 0.6010807595833223, 'min_child_weight': 5, 'gamma': 0.3053547659269517}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:59:43,109] Trial 13 finished with value: 9.893006913034517 and parameters: {'max_depth': 8, 'learning_rate': 0.06237512924200213, 'n_estimators': 166, 'subsample': 0.9239124345965728, 'colsample_bytree': 0.581547687672132, 'min_child_weight': 8, 'gamma': 1.135695058254392}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:59:49,915] Trial 14 finished with value: 8.5650667746025 and parameters: {'max_depth': 6, 'learning_rate': 0.08332875370903543, 'n_estimators': 176, 'subsample': 0.7883748688419223, 'colsample_bytree': 0.8095839387020464, 'min_child_weight': 4, 'gamma': 1.1515907524661027}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 16:59:55,106] Trial 15 finished with value: 10.472055621230794 and parameters: {'max_depth': 10, 'learning_rate': 0.06963575592582276, 'n_estimators': 134, 'subsample': 0.7016792848320459, 'colsample_bytree': 0.6052147140693372, 'min_child_weight': 7, 'gamma': 0.7325166404003178}. Best is trial 0 with value: 7.974171163993951.
# [I 2026-06-29 17:00:02,605] Trial 16 finished with value: 7.708851039953379 and parameters: {'max_depth': 5, 'learning_rate': 0.05292905942490011, 'n_estimators': 179, 'subsample': 0.9151883989810299, 'colsample_bytree': 0.7947992509228796, 'min_child_weight': 1, 'gamma': 1.8698885287079223}. Best is trial 16 with value: 7.708851039953379.
# [I 2026-06-29 17:00:07,566] Trial 17 finished with value: 8.086309450383752 and parameters: {'max_depth': 5, 'learning_rate': 0.04698476411468058, 'n_estimators': 98, 'subsample': 0.8805304594988683, 'colsample_bytree': 0.7997509191284597, 'min_child_weight': 1, 'gamma': 1.9218415407555063}. Best is trial 16 with value: 7.708851039953379.
# [I 2026-06-29 17:00:14,503] Trial 18 finished with value: 8.090427503083857 and parameters: {'max_depth': 5, 'learning_rate': 0.05259113895151911, 'n_estimators': 170, 'subsample': 0.8154887416097092, 'colsample_bytree': 0.8285726521637807, 'min_child_weight': 3, 'gamma': 1.7919514239527088}. Best is trial 16 with value: 7.708851039953379.
# [I 2026-06-29 17:00:20,678] Trial 19 finished with value: 7.821902069627174 and parameters: {'max_depth': 6, 'learning_rate': 0.0493295804270662, 'n_estimators': 143, 'subsample': 0.9171423738421453, 'colsample_bytree': 0.7696363894573159, 'min_child_weight': 1, 'gamma': 3.7345896581741815}. Best is trial 16 with value: 7.708851039953379.

# %%
#best hyperparameters Ridge
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'max_depth': 5, 'learning_rate': 0.05292905942490011, 'n_estimators': 179, 'subsample': 0.9151883989810299, 'colsample_bytree': 0.7947992509228796, 'min_child_weight': 1, 'gamma': 1.8698885287079223}

# %%
# Treinar modelo final
best_model = XGBRegressor(
    max_depth=study.best_params['max_depth'],
    learning_rate=study.best_params['learning_rate'],
    n_estimators=study.best_params['n_estimators'],
    subsample=study.best_params['subsample'],
    alpcolsample_bytreeha=study.best_params['colsample_bytree'],
    min_child_weight=study.best_params['min_child_weight'],
    gamma=study.best_params['gamma'],
    random_state=42
)

best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 0.5483
# MAE:  0.3979
# MAPE: 0.0554%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()

# %%
# Valores shapĺey
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

# %%
# shap beer plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="dot", show=False)
plt.tight_layout()
plt.show()

# %%
# shap bar plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="bar", show=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## VotinRegressor

# %%
#function Optuna -- Voting Regressor
def objective(trial):
    # 1. Define hyperparameters to tune
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 200)
    rf_max_leaf_nodes = trial.suggest_int('rf_max_leaf_nodes', 2, 256)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 5, 100)
    rf_max_depth = trial.suggest_int('rf_max_depth', 5, 20, log=True)
    
    ridge_alpha = trial.suggest_float('ridge_alpha', 0.1, 100)
    
    knn_neighbors = trial.suggest_int('knn_neighbors', 1, 10)
    knn_weights = trial.suggest_categorical('knn_weights', ['uniform', 'distance'])
    
    xgb_max_depth = trial.suggest_int('xgb_max_depth', 3, 10)
    xgb_learning_rate = trial.suggest_float('xgb_learning_rate', 0.01, 0.3)
    xgb_n_estimators = trial.suggest_int('xgb_n_estimators', 50, 200)
    
    # 2. Expanding window parameters
    initial_train_size = 10
    step_size = 1
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        rf_model = RandomForestRegressor(
            n_estimators=rf_n_estimators,
            max_leaf_nodes=rf_max_leaf_nodes,
            min_samples_split=rf_min_samples_split,
            max_depth=rf_max_depth,
            random_state=42
        )
        
        ridge_model = Ridge(alpha=ridge_alpha)
        
        knn_model = KNeighborsRegressor(
            n_neighbors=knn_neighbors,
            weights=knn_weights
        )
        
        xgb_model = XGBRegressor(
            max_depth=xgb_max_depth,
            learning_rate=xgb_learning_rate,
            n_estimators=xgb_n_estimators,
            random_state=42
        )
        
        voting_model = VotingRegressor(
            estimators=[('rf', rf_model), ('ridge', ridge_model), ('knn', knn_model), ('xgb', xgb_model)]
        )
        
        voting_model.fit(X_train, y_train)
        preds = voting_model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = np.sqrt(mean_squared_error(y_val, preds))
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna Voting Regressor
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 17:00:21,320] A new study created in memory with name: no-name-398f191e-5896-4b84-b12c-bd44b0d353f9
# [I 2026-06-29 17:00:31,178] Trial 0 finished with value: 11.792565249856102 and parameters: {'rf_n_estimators': 106, 'rf_max_leaf_nodes': 244, 'rf_min_samples_split': 75, 'rf_max_depth': 11, 'ridge_alpha': 15.686262180199408, 'knn_neighbors': 2, 'knn_weights': 'distance', 'xgb_max_depth': 7, 'xgb_learning_rate': 0.21534104756085318, 'xgb_n_estimators': 53}. Best is trial 0 with value: 11.792565249856102.
# [I 2026-06-29 17:00:45,887] Trial 1 finished with value: 10.096192635823458 and parameters: {'rf_n_estimators': 196, 'rf_max_leaf_nodes': 214, 'rf_min_samples_split': 25, 'rf_max_depth': 6, 'ridge_alpha': 18.42211053435804, 'knn_neighbors': 4, 'knn_weights': 'uniform', 'xgb_max_depth': 5, 'xgb_learning_rate': 0.18743733946949004, 'xgb_n_estimators': 71}. Best is trial 1 with value: 10.096192635823458.
# [I 2026-06-29 17:00:56,787] Trial 2 finished with value: 13.409992493491133 and parameters: {'rf_n_estimators': 94, 'rf_max_leaf_nodes': 95, 'rf_min_samples_split': 48, 'rf_max_depth': 15, 'ridge_alpha': 20.04741083762014, 'knn_neighbors': 6, 'knn_weights': 'uniform', 'xgb_max_depth': 7, 'xgb_learning_rate': 0.059451995869314544, 'xgb_n_estimators': 59}. Best is trial 1 with value: 10.096192635823458.
# [I 2026-06-29 17:01:23,126] Trial 3 finished with value: 13.389863791753951 and parameters: {'rf_n_estimators': 193, 'rf_max_leaf_nodes': 248, 'rf_min_samples_split': 82, 'rf_max_depth': 7, 'ridge_alpha': 9.857444189237748, 'knn_neighbors': 7, 'knn_weights': 'uniform', 'xgb_max_depth': 6, 'xgb_learning_rate': 0.019972671123413333, 'xgb_n_estimators': 187}. Best is trial 1 with value: 10.096192635823458.
# [I 2026-06-29 17:01:33,427] Trial 4 finished with value: 10.416906306124362 and parameters: {'rf_n_estimators': 89, 'rf_max_leaf_nodes': 170, 'rf_min_samples_split': 34, 'rf_max_depth': 10, 'ridge_alpha': 54.71635690639364, 'knn_neighbors': 2, 'knn_weights': 'uniform', 'xgb_max_depth': 10, 'xgb_learning_rate': 0.26949993162401814, 'xgb_n_estimators': 140}. Best is trial 1 with value: 10.096192635823458.
# [I 2026-06-29 17:01:48,211] Trial 5 finished with value: 10.061507265582232 and parameters: {'rf_n_estimators': 189, 'rf_max_leaf_nodes': 24, 'rf_min_samples_split': 23, 'rf_max_depth': 5, 'ridge_alpha': 32.60050004325011, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 5, 'xgb_learning_rate': 0.09147100780934041, 'xgb_n_estimators': 131}. Best is trial 5 with value: 10.061507265582232.
# [I 2026-06-29 17:01:59,762] Trial 6 finished with value: 8.850001794525296 and parameters: {'rf_n_estimators': 71, 'rf_max_leaf_nodes': 206, 'rf_min_samples_split': 12, 'rf_max_depth': 20, 'ridge_alpha': 77.24725245273608, 'knn_neighbors': 2, 'knn_weights': 'distance', 'xgb_max_depth': 8, 'xgb_learning_rate': 0.2214120787318863, 'xgb_n_estimators': 166}. Best is trial 6 with value: 8.850001794525296.
# [I 2026-06-29 17:02:08,919] Trial 7 finished with value: 9.723662111080108 and parameters: {'rf_n_estimators': 61, 'rf_max_leaf_nodes': 93, 'rf_min_samples_split': 16, 'rf_max_depth': 17, 'ridge_alpha': 62.36748287007304, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 5, 'xgb_learning_rate': 0.22158579171803858, 'xgb_n_estimators': 146}. Best is trial 6 with value: 8.850001794525296.
# [I 2026-06-29 17:02:24,410] Trial 8 finished with value: 10.44984969299967 and parameters: {'rf_n_estimators': 183, 'rf_max_leaf_nodes': 122, 'rf_min_samples_split': 16, 'rf_max_depth': 13, 'ridge_alpha': 76.10242635682805, 'knn_neighbors': 6, 'knn_weights': 'uniform', 'xgb_max_depth': 7, 'xgb_learning_rate': 0.1339868953239794, 'xgb_n_estimators': 53}. Best is trial 6 with value: 8.850001794525296.
# [I 2026-06-29 17:02:38,038] Trial 9 finished with value: 13.806364608598003 and parameters: {'rf_n_estimators': 66, 'rf_max_leaf_nodes': 10, 'rf_min_samples_split': 66, 'rf_max_depth': 7, 'ridge_alpha': 50.90621204735381, 'knn_neighbors': 10, 'knn_weights': 'distance', 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0763514679925705, 'xgb_n_estimators': 61}. Best is trial 6 with value: 8.850001794525296.
# [I 2026-06-29 17:02:52,604] Trial 10 finished with value: 11.865525000748702 and parameters: {'rf_n_estimators': 152, 'rf_max_leaf_nodes': 180, 'rf_min_samples_split': 98, 'rf_max_depth': 19, 'ridge_alpha': 97.93061021066814, 'knn_neighbors': 1, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.2875458119633852, 'xgb_n_estimators': 199}. Best is trial 6 with value: 8.850001794525296.
# [I 2026-06-29 17:03:04,521] Trial 11 finished with value: 8.843554720835364 and parameters: {'rf_n_estimators': 51, 'rf_max_leaf_nodes': 76, 'rf_min_samples_split': 6, 'rf_max_depth': 20, 'ridge_alpha': 73.26037517183372, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.2231377497934563, 'xgb_n_estimators': 165}. Best is trial 11 with value: 8.843554720835364.
# [I 2026-06-29 17:03:17,001] Trial 12 finished with value: 8.690691304510391 and parameters: {'rf_n_estimators': 59, 'rf_max_leaf_nodes': 63, 'rf_min_samples_split': 6, 'rf_max_depth': 19, 'ridge_alpha': 82.4472580785703, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.15912464772022475, 'xgb_n_estimators': 167}. Best is trial 12 with value: 8.690691304510391.
# [I 2026-06-29 17:03:25,875] Trial 13 finished with value: 9.615436061190815 and parameters: {'rf_n_estimators': 50, 'rf_max_leaf_nodes': 55, 'rf_min_samples_split': 7, 'rf_max_depth': 13, 'ridge_alpha': 99.52649706783617, 'knn_neighbors': 8, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.14401327993632712, 'xgb_n_estimators': 104}. Best is trial 12 with value: 8.690691304510391.
# [I 2026-06-29 17:03:36,923] Trial 14 finished with value: 12.212277244899493 and parameters: {'rf_n_estimators': 143, 'rf_max_leaf_nodes': 53, 'rf_min_samples_split': 40, 'rf_max_depth': 15, 'ridge_alpha': 80.22109056100906, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.18110631970258684, 'xgb_n_estimators': 167}. Best is trial 12 with value: 8.690691304510391.
# [I 2026-06-29 17:03:47,202] Trial 15 finished with value: 8.597108011408686 and parameters: {'rf_n_estimators': 113, 'rf_max_leaf_nodes': 68, 'rf_min_samples_split': 5, 'rf_max_depth': 20, 'ridge_alpha': 67.42069496418958, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.2537557856012104, 'xgb_n_estimators': 164}. Best is trial 15 with value: 8.597108011408686.
# [I 2026-06-29 17:03:55,769] Trial 16 finished with value: 9.594960057555621 and parameters: {'rf_n_estimators': 124, 'rf_max_leaf_nodes': 138, 'rf_min_samples_split': 31, 'rf_max_depth': 16, 'ridge_alpha': 87.0757373150788, 'knn_neighbors': 1, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.2533391110130563, 'xgb_n_estimators': 98}. Best is trial 15 with value: 8.597108011408686.
# [I 2026-06-29 17:04:07,784] Trial 17 finished with value: 12.321583703745155 and parameters: {'rf_n_estimators': 127, 'rf_max_leaf_nodes': 40, 'rf_min_samples_split': 59, 'rf_max_depth': 12, 'ridge_alpha': 37.694001449879096, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.12451682870043082, 'xgb_n_estimators': 181}. Best is trial 15 with value: 8.597108011408686.
# [I 2026-06-29 17:04:15,135] Trial 18 finished with value: 12.891227863711926 and parameters: {'rf_n_estimators': 84, 'rf_max_leaf_nodes': 125, 'rf_min_samples_split': 46, 'rf_max_depth': 9, 'ridge_alpha': 65.3232291569916, 'knn_neighbors': 5, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.29958988760163924, 'xgb_n_estimators': 115}. Best is trial 15 with value: 8.597108011408686.
# [I 2026-06-29 17:04:28,879] Trial 19 finished with value: 9.8904322904443 and parameters: {'rf_n_estimators': 169, 'rf_max_leaf_nodes': 2, 'rf_min_samples_split': 24, 'rf_max_depth': 9, 'ridge_alpha': 40.476458548192646, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 6, 'xgb_learning_rate': 0.18326755312991164, 'xgb_n_estimators': 155}. Best is trial 15 with value: 8.597108011408686.

# %%
#best hyperparameters Voting Regressor
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'rf_n_estimators': 113, 'rf_max_leaf_nodes': 68, 'rf_min_samples_split': 5, 'rf_max_depth': 20, 'ridge_alpha': 67.42069496418958, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.2537557856012104, 'xgb_n_estimators': 164}

# %%
# Treinar modelo final
best_model = VotingRegressor(
    estimators=[
        ('rf', RandomForestRegressor(
            n_estimators=study.best_params['rf_n_estimators'],
            max_leaf_nodes=study.best_params['rf_max_leaf_nodes'],
            min_samples_split=study.best_params['rf_min_samples_split'],
            max_depth=study.best_params['rf_max_depth'],
            random_state=42
        )),
        ('ridge', Ridge(alpha=study.best_params['ridge_alpha'])),
        ('knn', KNeighborsRegressor(
            n_neighbors=study.best_params['knn_neighbors'],
            weights=study.best_params['knn_weights']
        )),
        ('xgb', XGBRegressor(
            max_depth=study.best_params['xgb_max_depth'],
            learning_rate=study.best_params['xgb_learning_rate'],
            n_estimators=study.best_params['xgb_n_estimators'],
            random_state=42
        ))
    ]
)
 
best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 3.0160
# MAE:  2.3288
# MAPE: 0.3281%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()
