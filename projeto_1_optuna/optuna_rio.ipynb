# %% [markdown]
# ## Bibliotecas

# %%
#import packages
import pandas as pd
import numpy as np
import os
import warnings
import optuna
from sklearn.metrics import root_mean_squared_error, mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor, VotingRegressor
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
import shap
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# ## Configurações

# %%
# Definir diretório
os.chdir('/home/joao/Área de Trabalho/tese')

# Evitar avisos
warnings.filterwarnings('ignore')

# %%
#load dataset
df = pd.read_excel('df_conjunto_rio.xlsx')

# %%
#rename columns
df = df.rename(columns={
    'semana':'week',
    'cesta_dieese':'dieese_basket',
    'carne':'meat',
    'leite':'milk',
    'feijao':'bean',
    'arroz':'rice',
    'farinha':'flour',
    'batata':'potato',
    'tomate':'tomato',
    'pao':'bread',
    'cafe':'coffee',
    'acucar':'sugar',
    'oleo':'lard/oil',
    'manteiga':'butter',
    'cesta_online':'online'
})

# %%
df.columns
# Out:
# Index(['week', 'dieese_basket', 'meat', 'milk', 'bean', 'rice', 'flour',
#        'potato', 'tomato', 'bread', 'coffee', 'banana', 'sugar', 'lard/oil',
#        'butter', 'online'],
#       dtype='object')

# %%
#create lagged dataset
k = 1 #number of lags
y_lag = df[['week','dieese_basket']][k:]
x_lag = df.copy()
x_lag = x_lag.drop(['week','dieese_basket'], axis=1)
x_lag = x_lag[:len(df)-k]
y_lag = y_lag.reset_index(drop=True)
x_lag = x_lag.reset_index(drop=True)
df_lag = pd.concat([y_lag,x_lag], axis=1)

# %%
#set X and y
X = df_lag.copy()
X = X.drop(['week','dieese_basket','online'], axis=1)
y = df_lag['dieese_basket']

# %%
def calculate_mape(y_true, y_pred):
    mask = y_true != 0
    if mask.sum() == 0:
        return 0
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

# %% [markdown]
# ## Random forest

# %%
#function Optuna -- RF
def objective(trial):
    # 1. Define hyperparameters to tune
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 2, 256)
    min_samples_split = trial.suggest_int('min_samples_split', 5, 100)
    max_depth = trial.suggest_int('max_depth', 5, 20, log=True)
    
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = RandomForestRegressor(
            n_estimators=n_estimators,
            max_leaf_nodes=max_leaf_nodes,
            min_samples_split=min_samples_split,
            max_depth=max_depth,
            random_state=42
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna RF
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:46:59,856] A new study created in memory with name: no-name-fbd79d29-39ef-431d-a3cc-c2b2f822370a
# [I 2026-06-29 16:47:02,993] Trial 0 finished with value: 28.77094549596124 and parameters: {'n_estimators': 106, 'max_leaf_nodes': 244, 'min_samples_split': 75, 'max_depth': 11}. Best is trial 0 with value: 28.77094549596124.
# [I 2026-06-29 16:47:05,310] Trial 1 finished with value: 13.156693558639011 and parameters: {'n_estimators': 73, 'max_leaf_nodes': 41, 'min_samples_split': 10, 'max_depth': 17}. Best is trial 1 with value: 13.156693558639011.
# [I 2026-06-29 16:47:09,727] Trial 2 finished with value: 11.990507096134303 and parameters: {'n_estimators': 140, 'max_leaf_nodes': 182, 'min_samples_split': 6, 'max_depth': 20}. Best is trial 2 with value: 11.990507096134303.
# [I 2026-06-29 16:47:14,542] Trial 3 finished with value: 21.258517366394962 and parameters: {'n_estimators': 175, 'max_leaf_nodes': 56, 'min_samples_split': 22, 'max_depth': 6}. Best is trial 2 with value: 11.990507096134303.
# [I 2026-06-29 16:47:17,339] Trial 4 finished with value: 28.707611946158305 and parameters: {'n_estimators': 95, 'max_leaf_nodes': 135, 'min_samples_split': 46, 'max_depth': 7}. Best is trial 2 with value: 11.990507096134303.
# [I 2026-06-29 16:47:21,969] Trial 5 finished with value: 23.742028440968873 and parameters: {'n_estimators': 142, 'max_leaf_nodes': 37, 'min_samples_split': 33, 'max_depth': 8}. Best is trial 2 with value: 11.990507096134303.
# [I 2026-06-29 16:47:26,313] Trial 6 finished with value: 21.64837270093693 and parameters: {'n_estimators': 118, 'max_leaf_nodes': 202, 'min_samples_split': 24, 'max_depth': 10}. Best is trial 2 with value: 11.990507096134303.
# [I 2026-06-29 16:47:30,301] Trial 7 finished with value: 28.79160866978541 and parameters: {'n_estimators': 139, 'max_leaf_nodes': 13, 'min_samples_split': 63, 'max_depth': 6}. Best is trial 2 with value: 11.990507096134303.
# [I 2026-06-29 16:47:31,968] Trial 8 finished with value: 28.635985746254853 and parameters: {'n_estimators': 59, 'max_leaf_nodes': 243, 'min_samples_split': 97, 'max_depth': 15}. Best is trial 2 with value: 11.990507096134303.
# [I 2026-06-29 16:47:34,595] Trial 9 finished with value: 28.755692665686695 and parameters: {'n_estimators': 95, 'max_leaf_nodes': 26, 'min_samples_split': 70, 'max_depth': 9}. Best is trial 2 with value: 11.990507096134303.
# [I 2026-06-29 16:47:40,606] Trial 10 finished with value: 11.60371915023287 and parameters: {'n_estimators': 194, 'max_leaf_nodes': 144, 'min_samples_split': 5, 'max_depth': 19}. Best is trial 10 with value: 11.60371915023287.
# [I 2026-06-29 16:47:46,464] Trial 11 finished with value: 11.86756947622032 and parameters: {'n_estimators': 195, 'max_leaf_nodes': 148, 'min_samples_split': 6, 'max_depth': 20}. Best is trial 10 with value: 11.60371915023287.
# [I 2026-06-29 16:47:51,477] Trial 12 finished with value: 27.95050403723944 and parameters: {'n_estimators': 196, 'max_leaf_nodes': 111, 'min_samples_split': 42, 'max_depth': 13}. Best is trial 10 with value: 11.60371915023287.
# [I 2026-06-29 16:47:56,759] Trial 13 finished with value: 19.16014149598132 and parameters: {'n_estimators': 196, 'max_leaf_nodes': 123, 'min_samples_split': 18, 'max_depth': 20}. Best is trial 10 with value: 11.60371915023287.
# [I 2026-06-29 16:48:02,017] Trial 14 finished with value: 11.683902588329895 and parameters: {'n_estimators': 173, 'max_leaf_nodes': 170, 'min_samples_split': 5, 'max_depth': 14}. Best is trial 10 with value: 11.60371915023287.
# [I 2026-06-29 16:48:06,363] Trial 15 finished with value: 22.731270147431868 and parameters: {'n_estimators': 169, 'max_leaf_nodes': 84, 'min_samples_split': 30, 'max_depth': 13}. Best is trial 10 with value: 11.60371915023287.
# [I 2026-06-29 16:48:10,582] Trial 16 finished with value: 28.780363861299573 and parameters: {'n_estimators': 166, 'max_leaf_nodes': 186, 'min_samples_split': 54, 'max_depth': 16}. Best is trial 10 with value: 11.60371915023287.
# [I 2026-06-29 16:48:14,663] Trial 17 finished with value: 28.79018584668415 and parameters: {'n_estimators': 160, 'max_leaf_nodes': 162, 'min_samples_split': 88, 'max_depth': 13}. Best is trial 10 with value: 11.60371915023287.
# [I 2026-06-29 16:48:19,816] Trial 18 finished with value: 18.22901441407674 and parameters: {'n_estimators': 179, 'max_leaf_nodes': 92, 'min_samples_split': 17, 'max_depth': 16}. Best is trial 10 with value: 11.60371915023287.
# [I 2026-06-29 16:48:23,896] Trial 19 finished with value: 25.400639474931733 and parameters: {'n_estimators': 152, 'max_leaf_nodes': 203, 'min_samples_split': 37, 'max_depth': 5}. Best is trial 10 with value: 11.60371915023287.

# %%
#best hyperparameters RF
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'n_estimators': 194, 'max_leaf_nodes': 144, 'min_samples_split': 5, 'max_depth': 19}

# %%
# Treinar modelo final
best_model = RandomForestRegressor(
    n_estimators=study.best_params['n_estimators'],
    max_leaf_nodes=study.best_params['max_leaf_nodes'],
    min_samples_split=study.best_params['min_samples_split'],
    max_depth=study.best_params['max_depth'],
    random_state=42
)

best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 5.0304
# MAE:  2.9713
# MAPE: 0.3755%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()

# %%
# Valores shapĺey
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

# %%
# shap beer plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="dot", show=False)
plt.tight_layout()
plt.show()

# %%
# shap bar plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="bar", show=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ridge

# %%
#function Optuna -- Ridge
def objective(trial):
    # 1. Define hyperparameters to tune
    alpha = trial.suggest_float('alpha', 1e-5, 1e2, log=True)
        
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = Ridge(
            alpha=alpha,
            random_state=42
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna Ridge
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:48:24,572] A new study created in memory with name: no-name-3c7cc469-bb9a-41e3-9391-479ca75c09cf
# [I 2026-06-29 16:48:24,707] Trial 0 finished with value: 16.18389439715612 and parameters: {'alpha': 0.004185822729546971}. Best is trial 0 with value: 16.18389439715612.
# [I 2026-06-29 16:48:24,825] Trial 1 finished with value: 13.090633208522824 and parameters: {'alpha': 45.18560951024108}. Best is trial 1 with value: 13.090633208522824.
# [I 2026-06-29 16:48:24,913] Trial 2 finished with value: 12.635657380002293 and parameters: {'alpha': 1.330324510152291}. Best is trial 2 with value: 12.635657380002293.
# [I 2026-06-29 16:48:25,003] Trial 3 finished with value: 13.114769884403932 and parameters: {'alpha': 0.1550991398759431}. Best is trial 2 with value: 12.635657380002293.
# [I 2026-06-29 16:48:25,106] Trial 4 finished with value: 18.42198255037062 and parameters: {'alpha': 0.000123631882770522}. Best is trial 2 with value: 12.635657380002293.
# [I 2026-06-29 16:48:25,205] Trial 5 finished with value: 18.42209561651983 and parameters: {'alpha': 0.0001235838277230692}. Best is trial 2 with value: 12.635657380002293.
# [I 2026-06-29 16:48:25,307] Trial 6 finished with value: 18.668846872994838 and parameters: {'alpha': 2.550264850403285e-05}. Best is trial 2 with value: 12.635657380002293.
# [I 2026-06-29 16:48:25,390] Trial 7 finished with value: 12.520450960011983 and parameters: {'alpha': 11.567327199145982}. Best is trial 7 with value: 12.520450960011983.
# [I 2026-06-29 16:48:25,472] Trial 8 finished with value: 13.100720363652531 and parameters: {'alpha': 0.16136341713591323}. Best is trial 7 with value: 12.520450960011983.
# [I 2026-06-29 16:48:25,555] Trial 9 finished with value: 12.71947787179136 and parameters: {'alpha': 0.9047071957568393}. Best is trial 7 with value: 12.520450960011983.
# [I 2026-06-29 16:48:25,647] Trial 10 finished with value: 13.806875091472987 and parameters: {'alpha': 71.10754677213096}. Best is trial 7 with value: 12.520450960011983.
# [I 2026-06-29 16:48:25,734] Trial 11 finished with value: 12.45009194529031 and parameters: {'alpha': 6.512613790583885}. Best is trial 11 with value: 12.45009194529031.
# [I 2026-06-29 16:48:25,817] Trial 12 finished with value: 12.54231815561155 and parameters: {'alpha': 15.172246778478224}. Best is trial 11 with value: 12.45009194529031.
# [I 2026-06-29 16:48:25,902] Trial 13 finished with value: 12.455927813511334 and parameters: {'alpha': 4.567902784132975}. Best is trial 11 with value: 12.45009194529031.
# [I 2026-06-29 16:48:25,989] Trial 14 finished with value: 15.823838329065996 and parameters: {'alpha': 0.006032030579768758}. Best is trial 11 with value: 12.45009194529031.
# [I 2026-06-29 16:48:26,074] Trial 15 finished with value: 12.54668170798931 and parameters: {'alpha': 1.9895798459434357}. Best is trial 11 with value: 12.45009194529031.
# [I 2026-06-29 16:48:26,162] Trial 16 finished with value: 14.293115690214918 and parameters: {'alpha': 0.027606759056731205}. Best is trial 11 with value: 12.45009194529031.
# [I 2026-06-29 16:48:26,257] Trial 17 finished with value: 12.4505564090892 and parameters: {'alpha': 5.287541291750609}. Best is trial 11 with value: 12.45009194529031.
# [I 2026-06-29 16:48:26,343] Trial 18 finished with value: 12.992948998877301 and parameters: {'alpha': 0.24444745177180788}. Best is trial 11 with value: 12.45009194529031.
# [I 2026-06-29 16:48:26,458] Trial 19 finished with value: 14.291133697136251 and parameters: {'alpha': 92.72888379334282}. Best is trial 11 with value: 12.45009194529031.

# %%
#best hyperparameters Ridge
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'alpha': 6.512613790583885}

# %%
# Treinar modelo final
best_model = Ridge(
    alpha=study.best_params['alpha'],
    random_state=42
)

best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 10.5309
# MAE:  8.7573
# MAPE: 1.0996%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()

# %% [markdown]
# Ao executa o explainer abaixo gerou erro para o algoritmo `Ridge`. InvalidModelError: Model type not yet supported by TreeExplainer: <class 'sklearn.linear_model._ridge.Ridge'>

# %%
# Valores shapĺey
# explainer = shap.TreeExplainer(best_model)
# shap_values = explainer.shap_values(X)

# %% [markdown]
# ## KNN

# %%
#function Optuna -- kNN
def objective(trial):
    # 1. Define hyperparameters to tune
    n_neighbors = trial.suggest_int('n_neighbors', 1, 10)
    weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
    metric = trial.suggest_categorical('metric', ['euclidean', 'manhattan'])
        
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = KNeighborsRegressor(
            n_neighbors=n_neighbors,
            weights=weights,
            metric=metric
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna knn
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:48:26,611] A new study created in memory with name: no-name-17e38883-bab4-4847-8578-b8aac9efe60c
# [I 2026-06-29 16:48:26,712] Trial 0 finished with value: 11.55434210526316 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 0 with value: 11.55434210526316.
# [I 2026-06-29 16:48:26,804] Trial 1 finished with value: 6.238484220494245 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 1 with value: 6.238484220494245.
# [I 2026-06-29 16:48:26,896] Trial 2 finished with value: 5.342982456140354 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.342982456140354.
# [I 2026-06-29 16:48:26,988] Trial 3 finished with value: 7.42014059464714 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 2 with value: 5.342982456140354.
# [I 2026-06-29 16:48:27,101] Trial 4 finished with value: 13.037804073465388 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 2 with value: 5.342982456140354.
# [I 2026-06-29 16:48:27,192] Trial 5 finished with value: 13.69544830389667 and parameters: {'n_neighbors': 8, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 2 with value: 5.342982456140354.
# [I 2026-06-29 16:48:27,285] Trial 6 finished with value: 16.278696741854645 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 2 with value: 5.342982456140354.
# [I 2026-06-29 16:48:27,380] Trial 7 finished with value: 17.94269005847953 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.342982456140354.
# [I 2026-06-29 16:48:27,468] Trial 8 finished with value: 8.11 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 2 with value: 5.342982456140354.
# [I 2026-06-29 16:48:27,583] Trial 9 finished with value: 12.952830052981646 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 2 with value: 5.342982456140354.
# [I 2026-06-29 16:48:27,677] Trial 10 finished with value: 11.482543859649134 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 2 with value: 5.342982456140354.
# [I 2026-06-29 16:48:27,770] Trial 11 finished with value: 4.623157894736858 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 11 with value: 4.623157894736858.
# [I 2026-06-29 16:48:27,860] Trial 12 finished with value: 4.6231578947368455 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 4.6231578947368455.
# [I 2026-06-29 16:48:27,954] Trial 13 finished with value: 9.645557564913329 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 12 with value: 4.6231578947368455.
# [I 2026-06-29 16:48:28,041] Trial 14 finished with value: 4.6231578947368455 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 4.6231578947368455.
# [I 2026-06-29 16:48:28,129] Trial 15 finished with value: 9.67000000000002 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 4.6231578947368455.
# [I 2026-06-29 16:48:28,220] Trial 16 finished with value: 13.223684210526331 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 4.6231578947368455.
# [I 2026-06-29 16:48:28,309] Trial 17 finished with value: 4.6231578947368455 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 4.6231578947368455.
# [I 2026-06-29 16:48:28,414] Trial 18 finished with value: 9.67000000000002 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 4.6231578947368455.
# [I 2026-06-29 16:48:28,568] Trial 19 finished with value: 19.019438596491227 and parameters: {'n_neighbors': 10, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 12 with value: 4.6231578947368455.

# %%
#best hyperparameters knn
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan'}

# %%
# Treinar modelo final
best_model = KNeighborsRegressor(
    n_neighbors=study.best_params['n_neighbors'],
    weights=study.best_params['weights'],
    metric=study.best_params['metric']
)
best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 0.0000
# MAE:  0.0000
# MAPE: 0.0000%

# %% [markdown]
# ## XGBoost

# %%
#function Optuna -- XGB
def objective(trial):
    # 1. Define hyperparameters to tune
    max_depth = trial.suggest_int('max_depth', 3, 10)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.1)
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    gamma = trial.suggest_float('gamma', 0, 5)
        
    # 2. Expanding window parameters
    initial_train_size = 10  # Starting length of training data
    step_size = 1            # How much to expand the window per step
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        # Validation window directly follows the training window
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        model = XGBRegressor(
            max_depth = max_depth,
            learning_rate = learning_rate,
            n_estimators = n_estimators,
            subsample = subsample,
            colsample_bytree = colsample_bytree,
            min_child_weight = min_child_weight,
            gamma = gamma
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = root_mean_squared_error(y_val, preds)
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna XGB
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:48:28,611] A new study created in memory with name: no-name-7a3a8ace-1dc0-4852-8b32-e3908f60955c
# [I 2026-06-29 16:48:37,145] Trial 0 finished with value: 10.740836717036743 and parameters: {'max_depth': 5, 'learning_rate': 0.09556428757689246, 'n_estimators': 149, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'min_child_weight': 2, 'gamma': 0.2904180608409973}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:48:41,252] Trial 1 finished with value: 17.99951445997808 and parameters: {'max_depth': 9, 'learning_rate': 0.0641003510568888, 'n_estimators': 145, 'subsample': 0.5102922471479012, 'colsample_bytree': 0.9849549260809971, 'min_child_weight': 9, 'gamma': 1.0616955533913808}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:48:46,440] Trial 2 finished with value: 16.004791195518102 and parameters: {'max_depth': 4, 'learning_rate': 0.026506405886809047, 'n_estimators': 68, 'subsample': 0.762378215816119, 'colsample_bytree': 0.7159725093210578, 'min_child_weight': 3, 'gamma': 3.0592644736118975}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:48:50,897] Trial 3 finished with value: 12.688828724643649 and parameters: {'max_depth': 4, 'learning_rate': 0.03629301836816964, 'n_estimators': 79, 'subsample': 0.728034992108518, 'colsample_bytree': 0.8925879806965068, 'min_child_weight': 2, 'gamma': 2.571172192068058}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:48:55,347] Trial 4 finished with value: 22.870219940720958 and parameters: {'max_depth': 7, 'learning_rate': 0.014180537144799797, 'n_estimators': 126, 'subsample': 0.5852620618436457, 'colsample_bytree': 0.5325257964926398, 'min_child_weight': 10, 'gamma': 4.828160165372797}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:48:57,560] Trial 5 finished with value: 18.608280393366236 and parameters: {'max_depth': 9, 'learning_rate': 0.037415239225603365, 'n_estimators': 28, 'subsample': 0.8421165132560784, 'colsample_bytree': 0.7200762468698007, 'min_child_weight': 2, 'gamma': 2.475884550556351}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:49:00,847] Trial 6 finished with value: 13.317148822985208 and parameters: {'max_depth': 3, 'learning_rate': 0.09183883618709039, 'n_estimators': 59, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'min_child_weight': 6, 'gamma': 2.7335513967163982}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:49:06,013] Trial 7 finished with value: 11.256669793379944 and parameters: {'max_depth': 4, 'learning_rate': 0.09726261649881028, 'n_estimators': 158, 'subsample': 0.9697494707820946, 'colsample_bytree': 0.9474136752138245, 'min_child_weight': 6, 'gamma': 4.609371175115584}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:49:07,240] Trial 8 finished with value: 23.11258660567435 and parameters: {'max_depth': 3, 'learning_rate': 0.027638457617723072, 'n_estimators': 18, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'min_child_weight': 3, 'gamma': 4.143687545759647}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:49:12,753] Trial 9 finished with value: 12.528450263843212 and parameters: {'max_depth': 5, 'learning_rate': 0.03528410587186427, 'n_estimators': 113, 'subsample': 0.5704621124873813, 'colsample_bytree': 0.9010984903770198, 'min_child_weight': 1, 'gamma': 4.9344346830025865}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:49:28,413] Trial 10 finished with value: 11.509041598135974 and parameters: {'max_depth': 7, 'learning_rate': 0.07355202867601571, 'n_estimators': 195, 'subsample': 0.9661451709558936, 'colsample_bytree': 0.5076838686640521, 'min_child_weight': 5, 'gamma': 0.0757211855137844}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:49:46,710] Trial 11 finished with value: 11.246758412143649 and parameters: {'max_depth': 6, 'learning_rate': 0.09732045681737485, 'n_estimators': 184, 'subsample': 0.996871242919795, 'colsample_bytree': 0.8123826179152995, 'min_child_weight': 6, 'gamma': 1.3823654665598988}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:50:05,566] Trial 12 finished with value: 11.998327122738495 and parameters: {'max_depth': 6, 'learning_rate': 0.08074672937766333, 'n_estimators': 199, 'subsample': 0.8867325723956958, 'colsample_bytree': 0.8291904453927049, 'min_child_weight': 7, 'gamma': 1.051994970159623}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:50:18,791] Trial 13 finished with value: 11.053001216419965 and parameters: {'max_depth': 6, 'learning_rate': 0.09972562914474807, 'n_estimators': 169, 'subsample': 0.9934311625880041, 'colsample_bytree': 0.6174133489918274, 'min_child_weight': 4, 'gamma': 0.1437112289222957}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:50:28,531] Trial 14 finished with value: 11.52982601768093 and parameters: {'max_depth': 8, 'learning_rate': 0.08297665342550346, 'n_estimators': 162, 'subsample': 0.9002286548782846, 'colsample_bytree': 0.602298487430077, 'min_child_weight': 4, 'gamma': 0.24094571206617188}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:50:35,729] Trial 15 finished with value: 11.411741407963277 and parameters: {'max_depth': 5, 'learning_rate': 0.05895363106290675, 'n_estimators': 132, 'subsample': 0.7322686297568086, 'colsample_bytree': 0.5979644942759227, 'min_child_weight': 1, 'gamma': 1.6006171232777193}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:50:43,818] Trial 16 finished with value: 11.192071640282355 and parameters: {'max_depth': 5, 'learning_rate': 0.08587761099889374, 'n_estimators': 166, 'subsample': 0.795539459889861, 'colsample_bytree': 0.596609562772596, 'min_child_weight': 4, 'gamma': 0.618075494594877}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:50:48,485] Trial 17 finished with value: 13.316463387472597 and parameters: {'max_depth': 8, 'learning_rate': 0.07066952527593962, 'n_estimators': 98, 'subsample': 0.913217399679865, 'colsample_bytree': 0.6568835932453971, 'min_child_weight': 8, 'gamma': 1.947243227408607}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:50:58,346] Trial 18 finished with value: 12.066999083401875 and parameters: {'max_depth': 10, 'learning_rate': 0.04939150390314027, 'n_estimators': 170, 'subsample': 0.6594265389717751, 'colsample_bytree': 0.5562086123589665, 'min_child_weight': 4, 'gamma': 0.7108830786785898}. Best is trial 0 with value: 10.740836717036743.
# [I 2026-06-29 16:51:03,672] Trial 19 finished with value: 10.832608278508781 and parameters: {'max_depth': 6, 'learning_rate': 0.09876455681253653, 'n_estimators': 141, 'subsample': 0.6637389335441122, 'colsample_bytree': 0.7696363894573159, 'min_child_weight': 2, 'gamma': 3.6203000931356746}. Best is trial 0 with value: 10.740836717036743.

# %%
#best hyperparameters Ridge
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'max_depth': 5, 'learning_rate': 0.09556428757689246, 'n_estimators': 149, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'min_child_weight': 2, 'gamma': 0.2904180608409973}

# %%
# Treinar modelo final
best_model = XGBRegressor(
    max_depth=study.best_params['max_depth'],
    learning_rate=study.best_params['learning_rate'],
    n_estimators=study.best_params['n_estimators'],
    subsample=study.best_params['subsample'],
    alpcolsample_bytreeha=study.best_params['colsample_bytree'],
    min_child_weight=study.best_params['min_child_weight'],
    gamma=study.best_params['gamma'],
    random_state=42
)

best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 0.2567
# MAE:  0.1938
# MAPE: 0.0244%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()

# %%
# Valores shapĺey
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X)

# %%
# shap beer plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="dot", show=False)
plt.tight_layout()
plt.show()

# %%
# shap bar plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X, plot_type="bar", show=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## VotinRegressor

# %%
#function Optuna -- Voting Regressor
def objective(trial):
    # 1. Define hyperparameters to tune
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 200)
    rf_max_leaf_nodes = trial.suggest_int('rf_max_leaf_nodes', 2, 256)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 5, 100)
    rf_max_depth = trial.suggest_int('rf_max_depth', 5, 20, log=True)
    
    ridge_alpha = trial.suggest_float('ridge_alpha', 0.1, 100)
    
    knn_neighbors = trial.suggest_int('knn_neighbors', 1, 10)
    knn_weights = trial.suggest_categorical('knn_weights', ['uniform', 'distance'])
    
    xgb_max_depth = trial.suggest_int('xgb_max_depth', 3, 10)
    xgb_learning_rate = trial.suggest_float('xgb_learning_rate', 0.01, 0.3)
    xgb_n_estimators = trial.suggest_int('xgb_n_estimators', 50, 200)
    
    # 2. Expanding window parameters
    initial_train_size = 10
    step_size = 1
    total_samples = len(X)
    
    scores = []
    
    # 3. Walk-forward expanding window loop
    for train_end in range(initial_train_size, total_samples, step_size):
        X_train = X[:train_end]
        y_train = y[:train_end]
        
        X_val = X[train_end:train_end + step_size]
        y_val = y[train_end:train_end + step_size]
        
        if len(y_val) == 0:
            break
            
        # 4. Train and predict
        rf_model = RandomForestRegressor(
            n_estimators=rf_n_estimators,
            max_leaf_nodes=rf_max_leaf_nodes,
            min_samples_split=rf_min_samples_split,
            max_depth=rf_max_depth,
            random_state=42
        )
        
        ridge_model = Ridge(alpha=ridge_alpha)
        
        knn_model = KNeighborsRegressor(
            n_neighbors=knn_neighbors,
            weights=knn_weights
        )
        
        xgb_model = XGBRegressor(
            max_depth=xgb_max_depth,
            learning_rate=xgb_learning_rate,
            n_estimators=xgb_n_estimators,
            random_state=42
        )
        
        voting_model = VotingRegressor(
            estimators=[('rf', rf_model), ('ridge', ridge_model), ('knn', knn_model), ('xgb', xgb_model)]
        )
        
        voting_model.fit(X_train, y_train)
        preds = voting_model.predict(X_val)
        
        # 5. Evaluate and store score
        rmse = np.sqrt(mean_squared_error(y_val, preds))
        scores.append(rmse)
        
    # Return the mean error across all expanding window splits
    return np.mean(scores)

# %%
#run Optuna Voting Regressor
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=20)
# Out:
# [I 2026-06-29 16:51:04,267] A new study created in memory with name: no-name-8ac32cc7-a2c0-499f-a03c-71485877fb97
# [I 2026-06-29 16:51:11,695] Trial 0 finished with value: 12.490447038529185 and parameters: {'rf_n_estimators': 106, 'rf_max_leaf_nodes': 244, 'rf_min_samples_split': 75, 'rf_max_depth': 11, 'ridge_alpha': 15.686262180199408, 'knn_neighbors': 2, 'knn_weights': 'distance', 'xgb_max_depth': 7, 'xgb_learning_rate': 0.21534104756085318, 'xgb_n_estimators': 53}. Best is trial 0 with value: 12.490447038529185.
# [I 2026-06-29 16:51:22,279] Trial 1 finished with value: 12.274549282947321 and parameters: {'rf_n_estimators': 196, 'rf_max_leaf_nodes': 214, 'rf_min_samples_split': 25, 'rf_max_depth': 6, 'ridge_alpha': 18.42211053435804, 'knn_neighbors': 4, 'knn_weights': 'uniform', 'xgb_max_depth': 5, 'xgb_learning_rate': 0.18743733946949004, 'xgb_n_estimators': 71}. Best is trial 1 with value: 12.274549282947321.
# [I 2026-06-29 16:51:29,079] Trial 2 finished with value: 14.757578976251787 and parameters: {'rf_n_estimators': 94, 'rf_max_leaf_nodes': 95, 'rf_min_samples_split': 48, 'rf_max_depth': 15, 'ridge_alpha': 20.04741083762014, 'knn_neighbors': 6, 'knn_weights': 'uniform', 'xgb_max_depth': 7, 'xgb_learning_rate': 0.059451995869314544, 'xgb_n_estimators': 59}. Best is trial 1 with value: 12.274549282947321.
# [I 2026-06-29 16:51:47,441] Trial 3 finished with value: 14.810634996989778 and parameters: {'rf_n_estimators': 193, 'rf_max_leaf_nodes': 248, 'rf_min_samples_split': 82, 'rf_max_depth': 7, 'ridge_alpha': 9.857444189237748, 'knn_neighbors': 7, 'knn_weights': 'uniform', 'xgb_max_depth': 6, 'xgb_learning_rate': 0.019972671123413333, 'xgb_n_estimators': 187}. Best is trial 1 with value: 12.274549282947321.
# [I 2026-06-29 16:52:00,852] Trial 4 finished with value: 12.206083534491368 and parameters: {'rf_n_estimators': 89, 'rf_max_leaf_nodes': 170, 'rf_min_samples_split': 34, 'rf_max_depth': 10, 'ridge_alpha': 54.71635690639364, 'knn_neighbors': 2, 'knn_weights': 'uniform', 'xgb_max_depth': 10, 'xgb_learning_rate': 0.26949993162401814, 'xgb_n_estimators': 140}. Best is trial 4 with value: 12.206083534491368.
# [I 2026-06-29 16:52:21,319] Trial 5 finished with value: 12.193343619452747 and parameters: {'rf_n_estimators': 189, 'rf_max_leaf_nodes': 24, 'rf_min_samples_split': 23, 'rf_max_depth': 5, 'ridge_alpha': 32.60050004325011, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 5, 'xgb_learning_rate': 0.09147100780934041, 'xgb_n_estimators': 131}. Best is trial 5 with value: 12.193343619452747.
# [I 2026-06-29 16:52:46,414] Trial 6 finished with value: 10.69215833609267 and parameters: {'rf_n_estimators': 71, 'rf_max_leaf_nodes': 206, 'rf_min_samples_split': 12, 'rf_max_depth': 20, 'ridge_alpha': 77.24725245273608, 'knn_neighbors': 2, 'knn_weights': 'distance', 'xgb_max_depth': 8, 'xgb_learning_rate': 0.2214120787318863, 'xgb_n_estimators': 166}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:52:59,531] Trial 7 finished with value: 11.847377726510759 and parameters: {'rf_n_estimators': 61, 'rf_max_leaf_nodes': 93, 'rf_min_samples_split': 16, 'rf_max_depth': 17, 'ridge_alpha': 62.36748287007304, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 5, 'xgb_learning_rate': 0.22158579171803858, 'xgb_n_estimators': 146}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:53:09,918] Trial 8 finished with value: 13.325262590767645 and parameters: {'rf_n_estimators': 183, 'rf_max_leaf_nodes': 122, 'rf_min_samples_split': 16, 'rf_max_depth': 13, 'ridge_alpha': 76.10242635682805, 'knn_neighbors': 6, 'knn_weights': 'uniform', 'xgb_max_depth': 7, 'xgb_learning_rate': 0.1339868953239794, 'xgb_n_estimators': 53}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:53:17,149] Trial 9 finished with value: 15.39323102309097 and parameters: {'rf_n_estimators': 66, 'rf_max_leaf_nodes': 10, 'rf_min_samples_split': 66, 'rf_max_depth': 7, 'ridge_alpha': 50.90621204735381, 'knn_neighbors': 10, 'knn_weights': 'distance', 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0763514679925705, 'xgb_n_estimators': 61}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:53:28,110] Trial 10 finished with value: 13.281392485042165 and parameters: {'rf_n_estimators': 152, 'rf_max_leaf_nodes': 180, 'rf_min_samples_split': 98, 'rf_max_depth': 19, 'ridge_alpha': 97.93061021066814, 'knn_neighbors': 1, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.2875458119633852, 'xgb_n_estimators': 199}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:53:36,473] Trial 11 finished with value: 10.961669985150918 and parameters: {'rf_n_estimators': 51, 'rf_max_leaf_nodes': 76, 'rf_min_samples_split': 6, 'rf_max_depth': 20, 'ridge_alpha': 73.26037517183372, 'knn_neighbors': 4, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.2231377497934563, 'xgb_n_estimators': 165}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:53:46,538] Trial 12 finished with value: 10.871753902465661 and parameters: {'rf_n_estimators': 59, 'rf_max_leaf_nodes': 63, 'rf_min_samples_split': 6, 'rf_max_depth': 19, 'ridge_alpha': 82.4472580785703, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 3, 'xgb_learning_rate': 0.15912464772022475, 'xgb_n_estimators': 167}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:53:59,357] Trial 13 finished with value: 12.802824031062576 and parameters: {'rf_n_estimators': 130, 'rf_max_leaf_nodes': 51, 'rf_min_samples_split': 41, 'rf_max_depth': 13, 'ridge_alpha': 99.52649706783617, 'knn_neighbors': 1, 'knn_weights': 'distance', 'xgb_max_depth': 9, 'xgb_learning_rate': 0.14401327993632712, 'xgb_n_estimators': 104}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:54:10,792] Trial 14 finished with value: 10.882695210906922 and parameters: {'rf_n_estimators': 79, 'rf_max_leaf_nodes': 156, 'rf_min_samples_split': 8, 'rf_max_depth': 15, 'ridge_alpha': 82.06517809335051, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 8, 'xgb_learning_rate': 0.18110631970258684, 'xgb_n_estimators': 167}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:54:19,915] Trial 15 finished with value: 14.187125705778273 and parameters: {'rf_n_estimators': 116, 'rf_max_leaf_nodes': 128, 'rf_min_samples_split': 32, 'rf_max_depth': 20, 'ridge_alpha': 86.30963713865272, 'knn_neighbors': 9, 'knn_weights': 'distance', 'xgb_max_depth': 4, 'xgb_learning_rate': 0.2537557856012104, 'xgb_n_estimators': 164}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:54:29,716] Trial 16 finished with value: 12.957010610193379 and parameters: {'rf_n_estimators': 77, 'rf_max_leaf_nodes': 214, 'rf_min_samples_split': 58, 'rf_max_depth': 16, 'ridge_alpha': 38.106628524565224, 'knn_neighbors': 2, 'knn_weights': 'distance', 'xgb_max_depth': 8, 'xgb_learning_rate': 0.11942980389068858, 'xgb_n_estimators': 98}. Best is trial 6 with value: 10.69215833609267.
# [I 2026-06-29 16:54:41,970] Trial 17 finished with value: 10.576399357438573 and parameters: {'rf_n_estimators': 140, 'rf_max_leaf_nodes': 46, 'rf_min_samples_split': 5, 'rf_max_depth': 12, 'ridge_alpha': 64.99838039486436, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 6, 'xgb_learning_rate': 0.17355266271621556, 'xgb_n_estimators': 181}. Best is trial 17 with value: 10.576399357438573.
# [I 2026-06-29 16:54:53,625] Trial 18 finished with value: 12.998883134829672 and parameters: {'rf_n_estimators': 143, 'rf_max_leaf_nodes': 204, 'rf_min_samples_split': 20, 'rf_max_depth': 8, 'ridge_alpha': 67.6433865471618, 'knn_neighbors': 5, 'knn_weights': 'distance', 'xgb_max_depth': 6, 'xgb_learning_rate': 0.18557066096451105, 'xgb_n_estimators': 185}. Best is trial 17 with value: 10.576399357438573.
# [I 2026-06-29 16:55:04,461] Trial 19 finished with value: 13.948725168759392 and parameters: {'rf_n_estimators': 162, 'rf_max_leaf_nodes': 147, 'rf_min_samples_split': 37, 'rf_max_depth': 12, 'ridge_alpha': 40.352765985809974, 'knn_neighbors': 8, 'knn_weights': 'distance', 'xgb_max_depth': 8, 'xgb_learning_rate': 0.2575806114054714, 'xgb_n_estimators': 151}. Best is trial 17 with value: 10.576399357438573.

# %%
#best hyperparameters Voting Regressor
print("Best hyperparameters: ", study.best_params)
# Out:
# Best hyperparameters:  {'rf_n_estimators': 140, 'rf_max_leaf_nodes': 46, 'rf_min_samples_split': 5, 'rf_max_depth': 12, 'ridge_alpha': 64.99838039486436, 'knn_neighbors': 3, 'knn_weights': 'distance', 'xgb_max_depth': 6, 'xgb_learning_rate': 0.17355266271621556, 'xgb_n_estimators': 181}

# %%
# Treinar modelo final
best_model = VotingRegressor(
    estimators=[
        ('rf', RandomForestRegressor(
            n_estimators=study.best_params['rf_n_estimators'],
            max_leaf_nodes=study.best_params['rf_max_leaf_nodes'],
            min_samples_split=study.best_params['rf_min_samples_split'],
            max_depth=study.best_params['rf_max_depth'],
            random_state=42
        )),
        ('ridge', Ridge(alpha=study.best_params['ridge_alpha'])),
        ('knn', KNeighborsRegressor(
            n_neighbors=study.best_params['knn_neighbors'],
            weights=study.best_params['knn_weights']
        )),
        ('xgb', XGBRegressor(
            max_depth=study.best_params['xgb_max_depth'],
            learning_rate=study.best_params['xgb_learning_rate'],
            n_estimators=study.best_params['xgb_n_estimators'],
            random_state=42
        ))
    ]
)
 
best_model.fit(X, y)
y_pred = best_model.predict(X)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mape = calculate_mape(y, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
# Out:
# RMSE: 3.8490
# MAE:  3.0554
# MAPE: 0.3858%

# %%
# Pegar datas originais do DataFrame (alinhadas com y)
dates = pd.to_datetime(df['week'].values[:len(y)])
 
# Gráfico de Série Temporal
plt.figure(figsize=(12, 6))
plt.plot(dates, y, 'o-', label='DIEESE Basket', linewidth=2, markersize=4, color='#1f77b4', alpha=0.8)
plt.plot(dates, y_pred, 's--', label='Predicted', linewidth=2, markersize=4, color='#ff7f0e', alpha=0.8)
plt.xlabel('Week', fontsize=11, fontweight='bold')
plt.ylabel('Basket Value (R$)', fontsize=11, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
 
# Formatar datas no eixo X
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45, ha='right')
 
plt.tight_layout()
plt.show()
